# %%
import iatikit

# %%
iatikit.__version__
# Out:
# '2.1.0'

# %%
import sys

# !{sys.executable} -m pip install --upgrade iatikit
# Out:
# Collecting iatikit
#   Downloading https://files.pythonhosted.org/packages/b1/c1/8b0de2c6cfdb9df8e5c6cec9859efdcc71c0b03fd13d036f207b2d64a182/iatikit-2.1.0-py2.py3-none-any.whl (40kB)
# Requirement already satisfied, skipping upgrade: future in c:\users\alextilley\anaconda3\lib\site-packages (from iatikit) (0.17.1)
# Requirement already satisfied, skipping upgrade: requests in c:\users\alextilley\anaconda3\lib\site-packages (from iatikit) (2.21.0)
# Requirement already satisfied, skipping upgrade: configparser in c:\users\alextilley\anaconda3\lib\site-packages (from iatikit) (3.7.4)
# Requirement already satisfied, skipping upgrade: unicodecsv in c:\users\alextilley\anaconda3\lib\site-packages (from iatikit) (0.14.1)
# Requirement already satisfied, skipping upgrade: lxml in c:\users\alextilley\anaconda3\lib\site-packages (from iatikit) (4.2.5)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\alextilley\anaconda3\lib\site-packages (from requests->iatikit) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\alextilley\anaconda3\lib\site-packages (from requests->iatikit) (2018.11.29)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\alextilley\anaconda3\lib\site-packages (from requests->iatikit) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in c:\users\alextilley\anaconda3\lib\site-packages (from requests->iatikit) (1.24.1)
# Installing collected packages: iatikit
#   Found existing installation: iatikit 2.0.5
#     Uninstalling iatikit-2.0.5:
#       Successfully uninstalled iatikit-2.0.5
# Successfully installed iatikit-2.1.0

# %%
iatikit.download.data()

# %%
from datetime import datetime
import iatikit

registry = iatikit.data()

publishers = sorted(
    [(min([d.metadata.get('metadata_created')
           for d in p.datasets]
          ), p.metadata.get('title'))
     for p in registry.publishers])

for idx, tup in enumerate(publishers):
    print('{order}: {name} ({date})'.format(
        order=(idx + 1),
        name=tup[1],
        date=datetime.strptime(tup[0], '%Y-%m-%dT%H:%M:%S.%f').date()
    ))
# Out:
# 1: UK - Department for International Development (DFID) (2011-01-29)
# 2: The William and Flora Hewlett Foundation (2011-03-31)
# 3: The World Bank (2011-05-14)
# 4: Development Initiatives Poverty Research (2011-07-13)
# 5: Australia - Department of  Foreign Affairs and Trade (2011-09-02)
# 6: Netherlands - Ministry of Foreign Affairs (2011-09-19)
# 7: United Nations Office for Project Services (UNOPS) (2011-10-03)
# 8: Sweden, through Swedish International Development Cooperation Agency (Sida) (2011-11-11)
# 9: Oxfam GB (2011-11-25)
# 10: Finland - Ministry of Foreign Affairs (2011-11-25)
# 11: The Global Fund to Fight AIDS, Tuberculosis and Malaria (2011-11-25)
# 12: Asian Development Bank (2011-11-28)
# 13: Publish What You Fund (2011-11-29)
# 14: Resource Extraction Monitoring (2012-02-21)
# 15: ADRA-UK (2012-02-24)
# 16: Catholic Agency For Overseas Development (CAFOD) (2012-03-21)
# 17: GAVI Alliance (2012-03-30)
# 18: GlobalGiving.org (2012-05-09)
# 19: LEAD International (2012-05-24)
# 20: MapAction (2012-05-28)
# 21: Royal Society for the Protection of Birds (2012-05-31)
# 22: Transparency International Secretariat (2012-05-31)
# 23: HealthProm (2012-05-31)
# 24: Trocaire (Northern Ireland) (2012-05-31)
# 25: ChildHope UK (2012-06-01)
# 26: Send a Cow (2012-06-01)
# 27: Homeless International (2012-06-01)
# 28: Find Your Feet (2012-06-07)
# 29: Fauna & Flora International (2012-06-07)
# 30: BasicNeeds (2012-06-11)
# 31: Build Africa (2012-06-12)
# 32: ICA:UK (2012-06-12)
# 33: World Vision UK (2012-06-13)
# 34: Interact Worldwide (2012-06-13)
# 35: InterClimate Network (2012-06-14)
# 36: Children in Crisis (2012-06-15)
# 37: Trust for Africa's Orphans (2012-06-15)
# 38: Camfed International (2012-06-18)
# 39: War on Want (2012-06-27)
# 40: Power International (2012-07-11)
# 41: The International Children's Trust (2012-07-11)
# 42: Forests Monitor (2012-07-17)
# 43: Karuna Trust (2012-07-18)
# 44: Canon Collins Trust (2012-07-20)
# 45: World Association for Christian Communication (UK) (2012-07-20)
# 46: Womankind Worldwide (2012-08-01)
# 47: Survivors Fund (SURF) (2012-08-02)
# 48: SOS Sahel International UK (2012-08-06)
# 49: Friends of the Earth England, Wales and Northern Ireland (2012-08-08)
# 50: Pontis Foundation (2012-08-15)
# 51: Living Earth Foundation (2012-08-17)
# 52: UN-Habitat (2012-08-30)
# 53: African Initiatives (2012-09-04)
# 54: Sense International (2012-09-05)
# 55: WaterAid (2012-09-07)
# 56: Article19 (2012-09-21)
# 57: Water & Sanitation for the Urban Poor (WSUP) (2012-09-26)
# 58: Aga Khan Foundation (United Kingdom) (2012-10-02)
# 59: The Asia Foundation (2012-10-05)
# 60: Voluntary Service Overseas (VSO) (2012-10-26)
# 61: Relief International UK (2012-10-30)
# 62: Vision for a Nation Foundation (2012-11-12)
# 63: PONT (2012-11-15)
# 64: United Nations Development Programme (UNDP) (2012-12-13)
# 65: Twin (2012-12-17)
# 66: BRAC International (2012-12-19)
# 67: Conciliation Resources (2012-12-21)
# 68: United States (2013-01-02)
# 69: Jeevika Trust (2013-01-21)
# 70: APT Action on Poverty (2013-01-30)
# 71: Population Service International (2013-02-15)
# 72: Scottish Catholic International Aid Fund (SCIAF) (2013-02-22)
# 73: United Nations OCHA Financial Tracking Service (UN OCHA FTS) (2013-02-27)
# 74: World Wide Fund for Nature - Pakistan (2013-03-04)
# 75: Inter-American Development Bank (2013-03-08)
# 76: WWF-UK (2013-03-18)
# 77: ADD International (Action on Disability and Development) (2013-03-20)
# 78: Islamic Relief Worldwide (2013-03-20)
# 79: Railway Children (2013-03-26)
# 80: Gender Links (2013-03-26)
# 81: International Planned Parenthood Federation (2013-03-27)
# 82: Germany - Ministry for Economic Cooperation and Development (2013-03-28)
# 83: Restless Development (2013-03-28)
# 84: Leonard Cheshire Disability (2013-03-28)
# 85: Penal Reform International (2013-03-28)
# 86: Progressio (2013-03-28)
# 87: Malaria Consortium (2013-03-28)
# 88: Hope and Homes for Children (2013-04-08)
# 89: Practical Action (2013-04-09)
# 90: Agency for Cooperation and Research in Development (ACORD) (2013-04-16)
# 91: Centre for Indian Knowledge Systems (2013-04-29)
# 92: Pragya India (2013-04-30)
# 93: Farm Africa (2013-05-01)
# 94: UK - Home Office (2013-05-02)
# 95: The Global Alliance for Improved Nutrition (2013-05-07)
# 96: GOAL (2013-05-10)
# 97: People In Aid (2013-05-17)
# 98: Ethical Trading Initiative (2013-05-21)
# 99: Marie Stopes International (2013-05-24)
# 100: CDA Collaborative Learning Projects (2013-05-24)
# 101: Cord (2013-05-30)
# 102: Developments In Literacy Trust UK (2013-06-13)
# 103: United Nations Children's Fund (UNICEF) (2013-06-15)
# 104: Women for Women International (UK) (2013-06-18)
# 105: Association for Reproductive and Family Health (2013-06-24)
# 106: Child-to-Child (2013-06-24)
# 107: MicroLoan Foundation (2013-06-25)
# 108: Motivation (2013-06-26)
# 109: The Leprosy Mission England and Wales (2013-06-27)
# 110: African Development Bank (2013-06-27)
# 111: United Nations Population Fund (2013-07-02)
# 112: Y Care International (2013-07-09)
# 113: Freedom Forum (2013-07-11)
# 114: NGO Federation of Nepal (2013-07-17)
# 115: European Commission - Service for Foreign Policy Instruments (2013-07-23)
# 116: HelpAge International (2013-07-24)
# 117: Desmond Tutu HIV Foundation (2013-07-25)
# 118: Afghanaid (2013-07-28)
# 119: Cecily's Fund (2013-07-29)
# 120: Ireland - Department of Foreign Affairs and Trade (2013-07-31)
# 121: Canada - Global Affairs Canada | Affaires mondiales Canada (2013-07-31)
# 122: UK - Department for Work and Pensions (2013-08-02)
# 123: Akvo Foundation (2013-08-16)
# 124: Send a Cow Uganda (2013-09-02)
# 125: Development Aid from People to People (DAPP) Malawi (2013-09-04)
# 126: Medical Research Centre (MRC), Sierra Leone (2013-09-04)
# 127: Digital Campus (2013-09-10)
# 128: Blue Ventures Conservation (2013-09-11)
# 129: Southern African Catholic Bishops' Conference Aids Office (2013-09-12)
# 130: Concern Worldwide UK (2013-09-16)
# 131: Self Help Africa (2013-09-16)
# 132: Rainforest Foundation UK (2013-09-20)
# 133: Link Community Development Scotland (2013-09-20)
# 134: Oxfam India (2013-09-24)
# 135: European Commission - Humanitarian Aid & Civil Protection (2013-09-26)
# 136: Heifer International South Africa (2013-09-30)
# 137: Norwegian Refugee Council (2013-10-01)
# 138: Traidcraft Exchange (2013-10-02)
# 139: CUAMM Trustees (2013-10-07)
# 140: UK - Department of Health and Social Care (DHSC) (2013-10-11)
# 141: MICAIA (2013-10-18)
# 142: Plan International USA (2013-10-22)
# 143: Health Poverty Action (2013-10-24)
# 144: Climate Investment Funds (2013-10-25)
# 145: Afghanistan and Central Asian Association (2013-11-01)
# 146: UK - Medical Research Council (2013-11-01)
# 147: HTSPE (2013-11-27)
# 148: Triple Line (2013-11-29)
# 149: Coffey International Development (2013-12-02)
# 150: I Choose Life Africa (2013-12-04)
# 151: The Foundation Center (2013-12-04)
# 152: Emmanuel International UK (2013-12-05)
# 153: Bond (2013-12-12)
# 154: Integrity Action (2013-12-13)
# 155: DAI Europe (2013-12-17)
# 156: Target TB (2013-12-18)
# 157: Adam Smith International (2013-12-18)
# 158: AbleChildAfrica (2013-12-20)
# 159: Crown Agents Limited (2014-01-03)
# 160: France - Ministry for Europe and Foreign Affairs (2014-01-03)
# 161: Disability Rights Fund (2014-01-09)
# 162: Zimbabwe Educational Trust (2014-01-15)
# 163: Street Child (2014-01-15)
# 164: Dóchas - Irish Association of Non Governmental Development Organisations (2014-01-20)
# 165: Hilfswerk Austria Zimbabwe (2014-01-31)
# 166: Stars Foundation (2014-02-05)
# 167: United Nations World Food Programme (WFP) (2014-02-06)
# 168: Backward Society Education (BASE) (2014-02-10)
# 169: StreetInvest (2014-02-20)
# 170: Theatre for a Change UK (2014-02-20)
# 171: EveryChild (2014-02-21)
# 172: Grow Movement (2014-02-21)
# 173: Samaritan's Purse UK (2014-02-21)
# 174: Girls’ Education Challenge – Fund Manager PwC (2014-02-26)
# 175: Women and Children First (UK) (2014-03-05)
# 176: Viva (2014-03-05)
# 177: Plan Ireland Charitable Assistance Limited (2014-03-05)
# 178: Network for Africa (2014-03-05)
# 179: World University Service of Canada (2014-03-13)
# 180: CDC Group plc (2014-03-14)
# 181: Bill & Melinda Gates Foundation (2014-03-17)
# 182: Vision Aid Overseas (2014-03-19)
# 183: Saferworld (2014-03-28)
# 184: ARK (Absolute Return for Kids) (2014-03-28)
# 185: Social Impact Lab CIC (2014-03-31)
# 186: Spain - Ministry of Foreign Affairs and Cooperation (2014-04-01)
# 187: Switzerland - Swiss Agency for Development and Cooperation (SDC) (2014-04-02)
# 188: Indigo Trust (2014-04-03)
# 189: Adaptation Fund (2014-04-09)
# 190: Amref Health Africa - UK (2014-04-09)
# 191: Mercy Corps Europe (2014-04-22)
# 192: Excellent Development (2014-04-24)
# 193: SPARK (2014-04-28)
# 194: Lively Minds (2014-05-07)
# 195: Oxfam Novib (2014-05-08)
# 196: Avocats Sans Frontières (2014-05-13)
# 197: Fairtrade Labelling Organizations International e.V. (2014-05-16)
# 198: Aqua for All (2014-05-28)
# 199: GEMS Education Solutions (2014-05-29)
# 200: Water for People (2014-05-29)
# 201: UK - Department for Environment, Food and Rural Affairs (2014-05-30)
# 202: Rojiroti UK (2014-06-02)
# 203: Theatre for a Change Malawi (2014-06-17)
# 204: Network of International Development Organisations in Scotland (2014-06-19)
# 205: act4africa (2014-06-19)
# 206: FRANK Water (2014-06-20)
# 207: Micro Insurance Academy (2014-06-24)
# 208: United Nations Office for the Coordination of Humanitarian Affairs (OCHA) (2014-06-26)
# 209: Japan International Cooperation Agency (JICA) (2014-06-30)
# 210: All We Can (formerly Methodist Relief and Development Fund) (2014-07-04)
# 211: TB Alert (2014-07-07)
# 212: PHASE Worldwide (2014-07-11)
# 213: Pump Aid (2014-07-11)
# 214: One to One Children's Fund (2014-07-11)
# 215: Food for the Hungry UK (2014-07-11)
# 216: Retrak (2014-07-11)
# 217: UNITAID (2014-07-23)
# 218: Save the Children UK (2014-07-25)
# 219: PEAS (Promoting Equality in African Schools) (2014-07-27)
# 220: ACTED (2014-07-28)
# 221: Bioclimate Research and Development (2014-07-31)
# 222: Engineers Without Borders Canada (2014-08-01)
# 223: Teach A Man To Fish (2014-08-18)
# 224: AfriKids (2014-08-20)
# 225: Hagar International UK (2014-08-22)
# 226: Abaseen Foundation UK (2014-08-27)
# 227: ICS (2014-08-28)
# 228: RAIN Foundation (former) (2014-09-01)
# 229: partos (2014-09-01)
# 230: Twaweza (2014-09-02)
# 231: Fairfood International (2014-09-09)
# 232: Mifumi UK (2014-09-12)
# 233: World Child Cancer UK (2014-09-12)
# 234: Project Harar (2014-09-12)
# 235: The Open University (2014-09-12)
# 236: CODA International (2014-09-12)
# 237: Water Witness International (2014-09-22)
# 238: European Investment Bank (2014-09-26)
# 239: War Child UK (2014-10-09)
# 240: mothers2mothers (2014-10-10)
# 241: Denmark - Ministry of Foreign Affairs (2014-10-21)
# 242: Opportunity International UK (2014-10-22)
# 243: Haiti Hospital Appeal (2014-10-31)
# 244: The Coca-Cola Export Corporation (2014-10-31)
# 245: Friends of the Earth-Ghana (2014-11-06)
# 246: Lepra (2014-11-07)
# 247: Youth Business International (2014-11-07)
# 248: War on Want NI (2014-11-12)
# 249: Kepa ry (2014-12-04)
# 250: Bees Abroad UK (2014-12-05)
# 251: CRANE (2014-12-05)
# 252: interburns (2014-12-16)
# 253: Stromme Foundation (2014-12-22)
# 254: HelpAge International UK (2015-01-05)
# 255: Cyan International (2015-01-05)
# 256: iPartner India (2015-01-13)
# 257: PHASE Nepal (2015-01-15)
# 258: The Sabre Charitable Trust (2015-01-16)
# 259: Hospice Africa Ltd (2015-01-20)
# 260: ChildFund International (2015-01-20)
# 261: Stichting Humana (2015-01-23)
# 262: MAMTA - Health Institute for Mother and Child (2015-01-27)
# 263: Exeter Ethiopia Link (2015-01-27)
# 264: Rahnuma-Family Planning Assocation of Pakistan (2015-01-28)
# 265: CIFAL Scotland (2015-01-28)
# 266: Carers Worldwide (2015-01-31)
# 267: Discovery Learning Alliance, Inc. (2015-02-02)
# 268: Muslim Aid (2015-02-04)
# 269: ShelterBox (2015-02-06)
# 270: Tearfund (2015-02-06)
# 271: Feed the Minds (2015-02-06)
# 272: Signal (2015-02-06)
# 273: Private Infrastructure Development Group (2015-03-06)
# 274: Stichting Red een Kind (2015-03-11)
# 275: UK - Ministry of Defence (2015-03-12)
# 276: United Nations Educational, Scientific and Cultural Organization (UNESCO) (2015-03-16)
# 277: InterAction (2015-03-19)
# 278: Adventist Development and Relief Agency (ADRA Somalia) (2015-03-26)
# 279: Windle Trust Kenya (2015-04-02)
# 280: Agence Française de Développement (2015-04-10)
# 281: BBC Media Action (2015-04-17)
# 282: MAG (2015-04-17)
# 283: Anti-Slavery International (2015-04-17)
# 284: Natural Resource Governance Institute (NRGI) (2015-04-17)
# 285: Aasaman Nepal (2015-04-21)
# 286: Global Action Nepal (2015-04-21)
# 287: Stichting Aflatoun International (2015-04-21)
# 288: Welbodi Partnership (2015-04-22)
# 289: Shtrii Shakti (2015-04-27)
# 290: Canada Department of Finance / Ministère des Finances Canada (2015-05-01)
# 291: Canada - International Development Research Centre/Centre de recherches pour le développement international (2015-05-06)
# 292: European Bank for Reconstruction and Development (2015-05-14)
# 293: Action Against Hunger UK (2015-05-15)
# 294: Magariro (2015-05-21)
# 295: ANDA (2015-05-21)
# 296: United Purpose (2015-05-28)
# 297: Alfalit (2015-06-16)
# 298: Bees for Development Trust (2015-06-26)
# 299: Across (2015-06-30)
# 300: Romania Ministry of Foreign Affairs (2015-07-03)
# 301: Transparency International Bangladesh (2015-07-09)
# 302: ActionAid UK (2015-07-14)
# 303: Amref Flying Doctors (2015-07-20)
# 304: Christian Aid (2015-07-20)
# 305: Abt Associates Inc (2015-07-22)
# 306: Hand in Hand International (2015-07-30)
# 307: International Medical Corps UK (2015-08-13)
# 308: Lithuania, Ministry of Foreign Affairs (2015-08-28)
# 309: European Commission - Directorate-General for International Cooperation and Development (2015-09-14)
# 310: European Commission - Neighbourhood and Enlargement Negotiations (2015-09-14)
# 311: SOS Children's Villages Kenya (2015-09-16)
# 312: United Mission to Nepal (2015-09-30)
# 313: Varkey Foundation (2015-10-05)
# 314: World Vision International (2015-10-14)
# 315: AidData (2015-10-14)
# 316: KwaAfrica (2015-10-22)
# 317: MADE in Europe (2015-10-23)
# 318: British Red Cross (2015-10-29)
# 319: Zing (2015-11-02)
# 320: The Salvation Army International Development UK (2015-11-02)
# 321: International Procurement Agency (2015-11-11)
# 322: Nathan Associates London Ltd. (2015-11-11)
# 323: Global Partnership for Education (2015-11-16)
# 324: Wellfound (2015-11-17)
# 325: Plan International Finland (2015-11-30)
# 326: Options Consultancy Services (2015-12-02)
# 327: Ajuda de Desenvolvimento de Povo para Povo (ADPP) (2015-12-04)
# 328: Sympany+ (2015-12-08)
# 329: KPMG East Africa (2015-12-14)
# 330: PwC (2015-12-15)
# 331: Norad - Norwegian Agency for Development Cooperation (2015-12-17)
# 332: UK - Scottish Government (2015-12-17)
# 333: Palladium International Ltd (UK) (2015-12-20)
# 334: Alcis Holdings Limited (2015-12-23)
# 335: Maxwell Stamp PLC (2015-12-23)
# 336: WYG International B.V. (2015-12-23)
# 337: IOD PARC (2015-12-24)
# 338: Atos IT Services Ltd (2015-12-30)
# 339: Upper Quartile (2015-12-30)
# 340: McKinsey & Company (2016-01-05)
# 341: Oxford Policy Management (2016-01-05)
# 342: Free a Girl (2016-01-05)
# 343: Water Works (2016-01-27)
# 344: Itad (2016-01-29)
# 345: LAMB Health Care Foundation (2016-01-29)
# 346: Friends of Kipkelion (2016-02-04)
# 347: ZOA (2016-02-09)
# 348: KPMG LLP (2016-02-10)
# 349: Aktis Strategy Ltd (2016-02-17)
# 350: The OPEC Fund for International Development (OFID) (2016-02-18)
# 351: Christian Engineers in Development (2016-02-20)
# 352: InterAction's NGO Aid Map (2016-02-24)
# 353: Institute of Development Studies (2016-02-25)
# 354: Natural Resources Institute, University of Greenwich. (2016-03-04)
# 355: The Freedom Fund (2016-03-24)
# 356: Netherlands Institute for Multiparty Democracy (NIMD) (2016-04-15)
# 357: Mama Cash (2016-04-17)
# 358: International Labour Organization (ILO) (2016-04-18)
# 359: Defence for Children International Netherlands - ECPAT Netherlands (2016-04-18)
# 360: Urgent Action Fund Latin America and the Caribbean (2016-04-18)
# 361: Stichting Woord en Daad (2016-04-19)
# 362: Aids Fonds - STOP AIDS NOW! - Soa Aids Nederland (2016-04-19)
# 363: Urgent Action Fund-Africa (2016-04-20)
# 364: Africa Educational Trust (2016-04-20)
# 365: Friends of Publish What You Fund (2016-04-21)
# 366: Family Aids Caring Trust (2016-04-22)
# 367: Stichting Onderzoek Multinationale Ondernemingen (SOMO) (2016-04-25)
# 368: CREA (2016-04-25)
# 369: Both ENDS (2016-04-26)
# 370: GPPAC Foundation (2016-04-26)
# 371: Stichting ActionAId (2016-04-26)
# 372: Transnational Institute (2016-04-28)
# 373: Free Press Unlimited (2016-04-28)
# 374: Young Innovations Pvt. Ltd (2016-04-28)
# 375: Oxfam IBIS (2016-04-28)
# 376: CARE Nederland (2016-04-28)
# 377: Urgent Action Fund for Women's Human Rights (2016-04-28)
# 378: Stichting Health Action International (2016-04-28)
# 379: Wemos Foundation (2016-04-29)
# 380: Simavi (2016-04-29)
# 381: Association for Women's Rights in Development (AWID) (2016-04-29)
# 382: AWEPA (2016-04-29)
# 383: Save the Children Netherlands (2016-04-29)
# 384: Rutgers (2016-04-29)
# 385: Milieudefensie (2016-04-29)
# 386: WASTE advisers on urban environment and development (2016-04-29)
# 387: Netherlands Red Cross (2016-04-29)
# 388: WNF Wereld Natuur Fonds (2016-04-29)
# 389: Plan International Netherlands (2016-04-29)
# 390: Promundo-US (2016-04-29)
# 391: Royal Tropical Institute (2016-04-29)
# 392: Amnesty International The Netherlands (2016-04-30)
# 393: CHOICE for Youth and Sexuality (2016-04-30)
# 394: IRC (2016-05-01)
# 395: HE Foundation (2016-05-03)
# 396: Wetlands International (2016-05-03)
# 397: Tropenbos International (2016-05-03)
# 398: Red Cross Red Crescent Climate Centre (2016-05-04)
# 399: Sonke Gender Justice (2016-05-04)
# 400: Clean Clothes Campaign (2016-05-04)
# 401: International Development Law Organization (IDLO) (2016-05-12)
# 402: Fondo Centroamericano de Mujeres (2016-05-17)
# 403: Fair Wear Foundation (2016-05-19)
# 404: Protecting Families Against HIV/AIDS (2016-05-20)
# 405: CNV Internationaal (2016-05-20)
# 406: Mondiaal FNV (2016-05-20)
# 407: Hivos (2016-05-23)
# 408: Disasters Emergency Committee (2016-05-25)
# 409: International Climate Initiative / BMU - IKI Secretariat (2016-06-03)
# 410: Landell Mills (2016-06-05)
# 411: International Women's Development Agency (2016-06-06)
# 412: Dorcas Aid International (2016-06-06)
# 413: African Centre for Global Health and Social Transformation (2016-06-09)
# 414: Belgian development agency (Enabel) (2016-06-10)
# 415: Stichting Vluchteling (2016-06-14)
# 416: Disability and Development Partners (2016-06-20)
# 417: World Vision Netherlands (2016-06-23)
# 418: Christian Aid Ireland (2016-07-01)
# 419: Wageningen University & Research - Stichting Wageningen Research (2016-07-04)
# 420: Amref Health Africa Headquarters (2016-07-05)
# 421: dance4life (2016-07-20)
# 422: IUCN Nederlands Comité (2016-07-26)
# 423: BSR (2016-07-26)
# 424: AgriProFocus (2016-07-27)
# 425: PAX (2016-07-28)
# 426: COC Nederland (2016-07-29)
# 427: Terre des Hommes Netherlands (2016-07-31)
# 428: WO=MEN, Dutch Gender Platform (2016-07-31)
# 429: FMO (2016-08-01)
# 430: European Journalism Centre (2016-08-01)
# 431: UTZ (2016-08-01)
# 432: Republic of Korea (2016-08-08)
# 433: ColaLife (2016-08-09)
# 434: TEAR fund Nederland (2016-08-17)
# 435: International Alert (2016-09-08)
# 436: IMC WORLDWIDE (2016-09-29)
# 437: CABI (2016-09-29)
# 438: Internews Europe (2016-09-30)
# 439: APPRO-Europe (2016-10-01)
# 440: Afghanistan Public Policy Research Organization (APPRO) (2016-10-02)
# 441: United Nations Central Emergency Response Fund (CERF) (2016-10-03)
# 442: Doctors of the World UK (2016-10-19)
# 443: Acid Survivors Foundation (2016-10-19)
# 444: Friends of the Earth International (2016-10-20)
# 445: marysmeals (2016-10-26)
# 446: Amref Health Africa Malawi (2016-10-26)
# 447: SNV Netherlands Development Organisation (2016-10-28)
# 448: Pact (2016-11-07)
# 449: Omidyar Network Fund Inc. (2016-11-15)
# 450: The Convention on Business Integrity (2016-11-15)
# 451: One Acre Fund (2016-11-15)
# 452: Baylor College of Medicine Children's Foundation Malawi (2016-11-21)
# 453: Mensen met een Missie (2016-11-28)
# 454: Link Community Development International (2016-12-01)
# 455: Ministry of Foreign and European Affairs of the Slovak Republic (2016-12-08)
# 456: The Queen Elizabeth Diamond Jubilee Trust (2016-12-09)
# 457: Amref Health Africa in Ethiopia (2016-12-14)
# 458: openmindedly (2016-12-19)
# 459: Caritas Finland (2016-12-20)
# 460: United Nations Joint Programme on HIV and AIDS Secretariat (UNAIDS) (2016-12-21)
# 461: Plan International UK (2016-12-21)
# 462: Orbis Charitable Trust (2016-12-21)
# 463: IDH, the Sustainable Trade Initiative (2016-12-27)
# 464: Heifer Nederland (2016-12-30)
# 465: UN Women (2016-12-30)
# 466: Stichting Mayday Rescue Foundation (2017-01-10)
# 467: WASH Alliance International (2017-01-10)
# 468: International Rescue Committee UK (2017-01-20)
# 469: Ecorys UK (2017-01-23)
# 470: Mainline (2017-01-25)
# 471: Youth Net and Counselling - YONECO (2017-01-26)
# 472: Global Network of People Living with HIV (GNP+) (2017-01-27)
# 473: Solidaridad (2017-01-27)
# 474: International Finance Corporation (2017-01-28)
# 475: ICCO Cooperation (2017-01-30)
# 476: Norwegian People's Aid (2017-01-30)
# 477: Delivery Associates Ltd (2017-01-31)
# 478: Just Associates (2017-01-31)
# 479: Cardno Emerging Markets (2017-02-01)
# 480: Global Network of Sex Work Projects (NSWP) (2017-02-03)
# 481: DanChurchAid (2017-02-07)
# 482: Caritas Denmark (2017-02-09)
# 483: Amref Health Africa in Kenya (2017-02-09)
# 484: Aeras (2017-02-16)
# 485: Women Environmental Programme (2017-02-17)
# 486: World Economic Forum (2017-02-22)
# 487: International Treatment Preparedness Coalition (ITPC) (2017-02-25)
# 488: UK - Foreign & Commonwealth Office (2017-02-27)
# 489: The HALO Trust (2017-02-27)
# 490: Women's Environment & Development Organization (2017-02-27)
# 491: Women Peacemakers Program (2017-02-28)
# 492: Sightsavers (2017-03-03)
# 493: Centre For Citizens With Disabilities (2017-03-14)
# 494: Stichting Kinderpostzegels Nederland (2017-03-21)
# 495: UN Pooled Funds (2017-03-21)
# 496: AECOM (2017-03-30)
# 497: European Institute of Peace (2017-04-05)
# 498: Enhanced Integrated Framework (2017-04-07)
# 499: Ministère de l'Economie et des Finances du Bénin (2017-04-12)
# 500: International Network of People who Use Drugs (INPUD) (2017-04-12)
# 501: Sound Seekers Limited (2017-04-25)
# 502: Max Foundation (2017-04-26)
# 503: United States Agency for International Development (USAID) (2017-04-27)
# 504: The National Association of Municipalities of Benin (ANCB) (2017-04-28)
# 505: War Child Holland (2017-04-28)
# 506: Société Nationale des eaux du Bénin (SONEB) (2017-04-28)
# 507: Trianglen (2017-04-28)
# 508: HealthNet TPO (2017-05-02)
# 509: Food and Agriculture Organization of the United Nations (FAO) (2017-05-03)
# 510: International Union for Conservation of Nature and Natural Resources (2017-05-15)
# 511: Meningitis Research Foundation (2017-05-18)
# 512: International Network for Bamboo and Rattan (INBAR) (2017-05-19)
# 513: Arab foundation for freedoms and equality (2017-05-24)
# 514: Near East Foundation (NEF USA) (2017-06-07)
# 515: World Economic Forum Geneva (2017-06-08)
# 516: World Health Organization (2017-06-08)
# 517: Giro555 (Stichting Samenwerkende Hulporganisaties) (2017-06-12)
# 518: Support Trust for Africa Development (STAD) (2017-06-13)
# 519: Netherlands Enterprise Agency (2017-06-15)
# 520: EMMS International (2017-06-23)
# 521: MVO Nederland (2017-06-27)
# 522: PUM Netherlands (2017-06-27)
# 523: People in Need (2017-06-28)
# 524: Disability Rights Advocacy Fund (2017-06-29)
# 525: AICS - Agenzia Italiana per la Cooperazione allo Sviluppo / Italian Agency for Cooperation and Development (2017-06-30)
# 526: DAI Global Health (2017-07-04)
# 527: ActionAid International (2017-07-06)
# 528: Global Alliance for TB Drug Development (2017-07-06)
# 529: SECOURS CATHOLIQUE - CARITAS FRANCE (2017-07-11)
# 530: Win Win Strategies (2017-07-11)
# 531: AFEW International (2017-07-12)
# 532: Burns Violence Survivors - Nepal (2017-07-16)
# 533: Stichting Nederlands Instituut voor Internationale Betrekkingen 'Clingendael' (2017-07-20)
# 534: DNH Mali (Direction Nationale de l’Hydraulique du Mali) (2017-07-21)
# 535: IHE Delft Institute for Water Education (2017-07-27)
# 536: United Work (2017-07-30)
# 537: Local Development and Small Projects Support (2017-07-31)
# 538: TradeMark East Africa (2017-08-01)
# 539: Mulanje Mission Hospital (2017-08-01)
# 540: TechnoServe (2017-08-03)
# 541: Learning for Life (2017-08-03)
# 542: Conflict Dynamics International (2017-08-03)
# 543: Centre for Economic Policy Research (2017-08-04)
# 544: Palliative Care Support Trust (2017-08-07)
# 545: International IDEA (2017-08-07)
# 546: Association for Progressive Communication (2017-08-09)
# 547: Helvetas Swiss Intercooperation (2017-08-10)
# 548: IntraHealth International (2017-08-11)
# 549: New Zealand - Ministry of Foreign Affairs and Trade - New Zealand Aid Programme (2017-08-16)
# 550: Simprints (2017-08-17)
# 551: Caritas International (Belgium) (2017-08-22)
# 552: YMCA of Liberia (2017-08-23)
# 553: Mott MacDonald Limited (2017-08-29)
# 554: Amref Health Africa in Uganda (2017-08-30)
# 555: Education Development Trust (2017-08-30)
# 556: HiiL innovating Justice (2017-08-30)
# 557: Agência de Desenvolvimento do Vale do Zambeze (2017-08-30)
# 558: Handicap International UK (2017-09-07)
# 559: The International Rescue Committee (2017-09-08)
# 560: Construction Sector Transparency Initiative (CoST) (2017-09-11)
# 561: Union of Agricultural Work Committees (2017-09-12)
# 562: Siren Associates (2017-09-13)
# 563: World Federalist Movement - Institute for Global Policy (2017-09-15)
# 564: The Commonwealth Secretariat (2017-09-27)
# 565: Access to Seeds Foundation (2017-09-27)
# 566: Caritas Serbia (2017-09-28)
# 567: International Fund for Agricultural Development (IFAD) (2017-09-28)
# 568: IDEO.org (2017-09-29)
# 569: Overseas Development Institute (2017-10-02)
# 570: Atradius Dutch State Business (2017-10-05)
# 571: International Service (2017-10-11)
# 572: Girls Not Brides: The Global Partnership to End Child Marriage (2017-10-13)
# 573: ONG ALCRER (2017-10-20)
# 574: Social Watch Benin (2017-10-20)
# 575: CARE International UK (2017-10-26)
# 576: Solidaridad Europe (2017-10-29)
# 577: Human Relief Foundation (2017-10-31)
# 578: Women's Global Network on Reproductive Rights (2017-10-31)
# 579: DECP (2017-11-04)
# 580: International Bureau of Fiscal Documentation (IBFD) (2017-11-07)
# 581: Send a Cow Ethiopia (2017-11-13)
# 582: Oxfam America (2017-11-13)
# 583: University of Birmingham (2017-11-15)
# 584: VNG International (2017-11-17)
# 585: IPE Global Limited (2017-11-23)
# 586: TREE AID (2017-11-23)
# 587: UNICEF Netherlands National Committee (2017-11-29)
# 588: The Access to Nutrition Foundation (2017-11-30)
# 589: MannionDaniels (2017-12-04)
# 590: World Resources Institute (2017-12-04)
# 591: World Vision Zimbabwe (2017-12-05)
# 592: War Child Canada (2017-12-06)
# 593: ICF Consulting Services Ltd (2017-12-06)
# 594: United Nations Foundation (2017-12-06)
# 595: CARE International in Zimbabwe (2017-12-08)
# 596: Panos Institute West Africa (PIWA) (2017-12-13)
# 597: Save the Children International (2017-12-14)
# 598: Horizons for Green Development (2017-12-19)
# 599: Center for Research on Environment Health and Population Activities (CREHPA) (2017-12-20)
# 600: Medair (2017-12-20)
# 601: Global Innovation Fund (2017-12-20)
# 602: United Disabled Persons of Kenya (2017-12-28)
# 603: LIGHT FOR THE WORLD The Netherlands (2017-12-28)
# 604: Guttmacher Institute (2017-12-28)
# 605: University of Amsterdam (2017-12-28)
# 606: International Child Development Initiatives (2017-12-28)
# 607: The Hunger Project Netherlands (2017-12-28)
# 608: Women's Refugee Commission (2017-12-29)
# 609: Academy for Health Development (AHEAD) (2017-12-30)
# 610: African Population and Health Research Center (2018-01-02)
# 611: Ipas (2018-01-02)
# 612: GOGLA - Global Off-Grid Lighting Association (2018-01-03)
# 613: PricewaterhouseCoopers Private Limited India (2018-01-04)
# 614: Diakonia Sweden (2018-01-04)
# 615: Women's Action Group (2018-01-05)
# 616: SOS Children's Villages The Netherlands (2018-01-08)
# 617: Geneva Centre for the Democratic Control of Armed Forces (DCAF) (2018-01-08)
# 618: Integrity Research and Consultancy Ltd (2018-01-09)
# 619: UHAI EASHRI (2018-01-16)
# 620: World Waternet (2018-01-18)
# 621: FIAN Belgium (2018-01-22)
# 622: Search for Common Ground (SFCG) (2018-01-23)
# 623: United Nations Environment Programme (UNEP) (2018-01-26)
# 624: PRACTICA Foundation (2018-01-30)
# 625: CLASP (2018-02-05)
# 626: Amnesty International UK Section Charitable Trust (2018-02-08)
# 627: British & Irish Agencies Afghanistan Group (2018-02-08)
# 628: OCHA Country Based Pooled Funds (2018-02-20)
# 629: Belgian Development Cooperation (2018-02-20)
# 630: International Federation of Accountants (2018-02-22)
# 631: International Organization for Migration (IOM) (2018-02-23)
# 632: RUAF Foundation (2018-02-23)
# 633: Population Services and Training Centre (PSTC) (2018-02-27)
# 634: Charity Projects Ltd (Comic Relief) (2018-02-27)
# 635: IFOAM - Organics International (2018-02-27)
# 636: Millennium Challenge Corporation (2018-02-27)
# 637: Stichting fondsbeheer DGGF lokaal MKB (2018-02-28)
# 638: ODI Sales Limited (2018-02-28)
# 639: Nuffic (2018-02-28)
# 640: Climate Policy Initiative (2018-03-01)
# 641: COWI (2018-03-01)
# 642: EngenderHealth Ethiopia (2018-03-06)
# 643: UK - Department for Business, Energy and Industrial Strategy (2018-03-08)
# 644: Ethiopian Horticulture Producer Exporters Association (EHPEA) (2018-03-12)
# 645: Federation of Women Lawyers Kenya (2018-03-13)
# 646: Fundación Oriéntame (2018-03-16)
# 647: Centre National de Coopération au Développement (CNCD-11.11.11) (2018-03-21)
# 648: Economic and Social Research Foundation (ESRF) (2018-03-28)
# 649: African Center for Economic Transformation (ACET) (2018-03-29)
# 650: C40 Cities Climate Leadership Group (2018-03-30)
# 651: ABAAD - Resource Center for Gender Equality (2018-03-30)
# 652: Johns Hopkins University (2018-03-30)
# 653: United Nations Capital Development Fund (2018-04-05)
# 654: Bucks Community NGO (2018-04-06)
# 655: Development Organisation of the Rural Poor (2018-04-07)
# 656: Sensorial Handicap Cooperation (2018-04-09)
# 657: Clinton Health Access Initiative (2018-04-11)
# 658: Liverpool School of Tropical Medicine (2018-04-12)
# 659: International Initiative for Impact Evaluation (2018-04-13)
# 660: Orbis International (2018-04-13)
# 661: Orbis Ethiopia (2018-04-13)
# 662: The Power of Nutrition (2018-04-17)
# 663: Light For The World Belgium (2018-04-18)
# 664: Oxfam Intermón (2018-04-18)
# 665: Enfance Tiers Monde Kinderen Derde Wereld (2018-04-20)
# 666: VEI (Vitens-Evides International) (2018-04-20)
# 667: World Vision Syria (2018-04-20)
# 668: Association for Cultural Technical and Educational Cooperation (ACTEC) (2018-04-23)
# 669: Quinoa (2018-04-23)
# 670: VVSG - Vereniging van Vlaamse Steden en Gemeenten (2018-04-23)
# 671: VIA Don Bosco (2018-04-24)
# 672: GEOMOUN ASBL (2018-04-24)
# 673: Forum Universitaire pour la Coopération Internationale au Développement -FUCID ASBL (2018-04-24)
# 674: VVOB Education for Development (2018-04-24)
# 675: equileap (2018-04-24)
# 676: Entraide et Fraternité (2018-04-24)
# 677: Savana Signatures (2018-04-24)
# 678: Solsoc (2018-04-24)
# 679: Medecins du Monde Belgique - Dokters van de Wereld Belgïe (2018-04-24)
# 680: Bangladesh Nari Progati Sangha (2018-04-25)
# 681: Institute for International Workers Education (2018-04-25)
# 682: Association pour la Promotion de l'Education et de la Formation à l'Etranger (2018-04-25)
# 683: Centre Tricontinental - CETRI (2018-04-25)
# 684: Family Life Education Program (2018-04-25)
# 685: Chaîne de l'Espoir Belgique / Keten van Hoop België / Chain of Hope Belgium (2018-04-25)
# 686: BOS+ tropen (2018-04-25)
# 687: SCI Projets Internationaux ASBL_Service Civil International branche belge (2018-04-25)
# 688: Benelux Afro Center (2018-04-26)
# 689: Louvain Coopération (2018-04-26)
# 690: Network For Enterprise Enhancement and Development Support (2018-04-26)
# 691: SOS Kinderdorpen België / SOS Villages d'Enfants Belgique (2018-04-26)
# 692: Wereldsolidariteit-Solidarité Mondiale (WSM) (2018-04-26)
# 693: IREX (International Research and Exchange Board) (2018-04-26)
# 694: Fonds voor Ontwikkelingssamenwerking - Socialistische Solidariteit VZW (2018-04-26)
# 695: Union des Villes et Communes de Wallonie (UVCW) (2018-04-26)
# 696: Médecins Sans Vacances (2018-04-26)
# 697: Beweging voor Internationale Solidariteit - Mouvement pour la Solidarité Internationale (2018-04-26)
# 698: Oxfam-Magasins du monde (omdm) (2018-04-26)
# 699: Chama cha Uzazi na Malezi Bora Tanzania (UMATI) (2018-04-26)
# 700: Iles de Paix (2018-04-26)
# 701: NpM, Platform for Inclusive Finance (2018-04-26)
# 702: Brulocalis (2018-04-26)
# 703: VETERINAIRES SANS FRONTIERES / DIERENARTSEN ZONDER GRENZEN - BELGIUM (2018-04-26)
# 704: ECDPM (2018-04-26)
# 705: Miel Maya Honing asbl (2018-04-26)
# 706: Koepel van de Vlaamse Noord-Zuidbeweging 11.11.11 VZW (2018-04-27)
# 707: Studio Globo (2018-04-27)
# 708: Dynamo International asbl (2018-04-27)
# 709: Broederlijk Delen (2018-04-27)
# 710: Défi Belgique Afrique (2018-04-27)
# 711: Institut de Formation Syndical International (2018-04-27)
# 712: Unicef Belgium National Committee (2018-04-27)
# 713: Autre Terre asbl (2018-04-27)
# 714: ULB-Coopération (2018-04-27)
# 715: Fairtrade Belgium (2018-04-27)
# 716: Universitair Centrum voor Ontwikkelingssamenwerking (2018-04-27)
# 717: Viva Salud (2018-04-27)
# 718: ITECO - Centre de formation pour le développement (2018-04-27)
# 719: Handicap International Belgique (2018-04-27)
# 720: Rikolto (2018-04-27)
# 721: Memisa (2018-04-27)
# 722: Rikolto in Belgium (2018-04-27)
# 723: Rode Kruis-Vlaanderen Internationaal vzw (2018-04-27)
# 724: Croix-Rouge de Belgique Communauté francophone - Activités internationales ASBL (2018-04-27)
# 725: Protos (2018-04-27)
# 726: Coopération par l'Education et la Culture (2018-04-28)
# 727: Auto-Développement Afrique (ADA) (2018-04-29)
# 728: Echos Communication (2018-04-30)
# 729: SOS FAIM - SOS HUNGER (2018-04-30)
# 730: Solidagro (2018-04-30)
# 731: World Wide Fund for Nature Belgium (WWF-BE) (2018-04-30)
# 732: Institute of Tropical Medicine (2018-04-30)
# 733: COMMISSION JUSTICE ET PAIX ASBL (cjp) (2018-04-30)
# 734: KIYO (2018-04-30)
# 735: Oxfam Wereldwinkels (2018-04-30)
# 736: Congodorpen vzw (2018-04-30)
# 737: Oxfam Solidarité-Solidariteit (2018-04-30)
# 738: Rotary Clubs For Development (2018-04-30)
# 739: Trias (2018-04-30)
# 740: Right to Play Netherlands Foundation (2018-04-30)
# 741: ACODEV (2018-04-30)
# 742: Ngo-federatie (Vlaamse federatie van ngo's voor ontwikkelingssamenwerking) (2018-04-30)
# 743: Djapo VZW (2018-04-30)
# 744: Royal Netherlands Football Association (2018-04-30)
# 745: Orbis Africa (2018-04-30)
# 746: Tearfund VZW (TFBE) (2018-04-30)
# 747: Comité pour l'abolition des dettes illégitimes (2018-05-02)
# 748: Irise International (2018-05-02)
# 749: University of Leeds (2018-05-03)
# 750: UWEZO Youth Empowerment (2018-05-04)
# 751: VZW KBA FONCABA ASBL (2018-05-04)
# 752: Fiabel (2018-05-04)
# 753: Plan International Belgium (2018-05-06)
# 754: Voluntary Health Association of India (2018-05-08)
# 755: International NGO Safety Orgnisation (2018-05-08)
# 756: ACTION AGAINST HUNGER SPAIN (2018-05-08)
# 757: Centre for the Study of Adolescence (2018-05-14)
# 758: the center for victimized women and children (2018-05-15)
# 759: ADS-Nyanza (2018-05-16)
# 760: International Monetary Fund (2018-05-17)
# 761: Solidaridad West Africa (2018-05-25)
# 762: Solidaridad South & South-East Asia (2018-05-25)
# 763: Caribbean Development Bank (CDB) (2018-05-25)
# 764: Damiaanactie / Action Damien (2018-05-29)
# 765: Raleigh International (2018-05-30)
# 766: GiveDirectly (2018-05-31)
# 767: The University of Manchester (2018-06-01)
# 768: BRAC (2018-06-05)
# 769: Center for Civilians in Conflict (2018-06-06)
# 770: Royal College of General Practitioners (RCGP) (2018-06-08)
# 771: Stichting Aidenvironment (2018-06-12)
# 772: Amref Health Africa in Tanzania (2018-06-13)
# 773: Brigham and Women's Hospital (2018-06-14)
# 774: Chemonics International Inc. (2018-06-15)
# 775: YWCA of Bangladesh (2018-06-20)
# 776: Ethiopiaid UK (2018-06-20)
# 777: Royal College of Obstetricians & Gynaecologists (2018-06-22)
# 778: Netherlands Commission for Environmental Assessment (2018-06-27)
# 779: The Carter Center (2018-06-28)
# 780: Administração de Infra-Estruturas de Águas e Saneamento (2018-06-28)
# 781: Fundo de Investimento e Patrimonio do Abastecimento de Água (FIPAG) (2018-06-29)
# 782: Relief International - Somalia (2018-07-04)
# 783: Aga Khan Foundation Afghanistan (2018-07-05)
# 784: Ecorys Nederland B.V. (2018-07-05)
# 785: Concern Worldwide (2018-07-13)
# 786: Concordis International (2018-07-13)
# 787: Multilateral Investment Fund (2018-07-13)
# 788: Joshua Orphan and Community Care (2018-07-14)
# 789: Alliance of Religions and Conservation (2018-07-16)
# 790: CINI (2018-07-17)
# 791: World Agroforestry Centre (2018-07-18)
# 792: Danish Refugee Council (2018-07-18)
# 793: Social Fund for Development, Yemen (2018-07-19)
# 794: Musalaha Ministry of Reconciliation (2018-07-20)
# 795: The Princess Alia Foundation (2018-07-21)
# 796: United Nations Industrial Development Organization (UNIDO) (2018-07-23)
# 797: Social Development Direct Limited (2018-07-27)
# 798: Kesho Kenya (2018-07-31)
# 799: Ananda Marga Universal Relief Team (AMURT) Africa (2018-07-31)
# 800: University College London (2018-07-31)
# 801: AIDSPAN (2018-08-01)
# 802: AVSI FOUNDATION IN UGANDA (2018-08-02)
# 803: Acumen (2018-08-02)
# 804: Fundacion Acceso (2018-08-08)
# 805: Transparency International Kenya (2018-08-09)
# 806: Mzumbe University (2018-08-12)
# 807: Energy Saving Trust (2018-08-16)
# 808: United Nations Office for the Coordination of Humanitarian Affairs (Specially-Designated Contributions) (2018-08-17)
# 809: DKT - (Pakistan) (2018-08-18)
# 810: Stichting Agriterra (2018-08-20)
# 811: Collectif Stratégies Alimentaires (2018-08-21)
# 812: AgResults Initiative (2018-08-22)
# 813: Kisumu Medical and Education Trust (2018-08-23)
# 814: American Friends Service Committee (2018-08-30)
# 815: Afrikagrupperna Sweden (2018-08-30)
# 816: Institut National de l'Eau, Benin (2018-08-30)
# 817: Commune de Klouékanmè - Bénin (2018-08-30)
# 818: Commune de Ifangni - Bénin (2018-08-30)
# 819: Commune de Avrankou - Bénin (2018-08-31)
# 820: Commune de Comè - Bénin (2018-08-31)
# 821: Commune de Akpro-Missérété - Bénin (2018-08-31)
# 822: Commune de Bopa - Bénin (2018-08-31)
# 823: Commune de Pobè - Bénin (2018-08-31)
# 824: Commune de Adjohoun - Bénin (2018-08-31)
# 825: Tropical Health and Education Trust (2018-08-31)
# 826: Commune de Kétou - Bénin (2018-08-31)
# 827: Commune de Lalo - Bénin (2018-08-31)
# 828: Commune de Aplahoué - Bénin (2018-08-31)
# 829: Commune de Allada - Bénin (2018-08-31)
# 830: Commune de Zè - Bénin (2018-08-31)
# 831: Commune de Kpomassè - Bénin (2018-08-31)
# 832: Commune de Toffo - Bénin (2018-08-31)
# 833: Commune de Parakou - Bénin (2018-08-31)
# 834: Agence Nationale d'Approvisionnement en Eau Potable en Milieu Rural du Benin (2018-08-31)
# 835: Pastoralist Girls Initiative (2018-09-04)
# 836: United Nations High Commissioner for Refugees (UNHCR) (2018-09-04)
# 837: International Federation of the Red Cross and Red Crescent (IFRC) (2018-09-06)
# 838: Africalia (2018-09-07)
# 839: Stichting VU Amsterdam - Amsterdam Centre for World Food Studies (2018-09-10)
# 840: Netherlands Leprosy Relief (2018-09-10)
# 841: Global Green Growth Institute (GGGI) (2018-09-11)
# 842: We Effect (2018-09-12)
# 843: Send a Cow Kenya (2018-09-13)
# 844: Northern Rangelands Trust (2018-09-17)
# 845: Water Integrity Network Association (2018-09-19)
# 846: Académie de recherche et d'enseignement supérieur (2018-09-26)
# 847: Deloitte Touche Tohmatsu India LLP (2018-09-27)
# 848: CIVICUS World Alliance for Citizen Participation (2018-09-27)
# 849: Vlaamse Interuniversitaire Raad voor Universitaire Ontwikkelingssamenwerking (VLIR-UOS) (2018-09-28)
# 850: Association of Commonwealth Universities (2018-09-28)
# 851: RCN Justice & Démocratie (2018-10-08)
# 852: Queen Rania Foundation for Education and Development (2018-10-08)
# 853: The MENTOR Initiative (2018-10-08)
# 854: Kadaster International (2018-10-11)
# 855: Global Rights Compliance (2018-10-15)
# 856: Ministry of Foreign Affairs of  Japan (2018-10-16)
# 857: National Coalition of Human Rights Defenders - Kenya (2018-10-16)
# 858: Seefar (2018-10-18)
# 859: Commune de Toviklin - Bénin (2018-10-18)
# 860: The Global Forum on MSM & HIV (MSMGF) (2018-10-19)
# 861: Commune de Dangbo - Benin (2018-10-19)
# 862: Commune de Adjarra - Bénin (2018-10-19)
# 863: Commune de Adja-Ouere - Bénin (2018-10-19)
# 864: Christian Blind Mission (UK) Ltd. (2018-10-22)
# 865: Mastercard Foundation (2018-10-24)
# 866: Rehabilitation, Education and Community Health (REACH) (2018-10-25)
# 867: Water Finance Facility (2018-10-31)
# 868: Access to Medicine Foundation (2018-10-31)
# 869: Berytech Foundation (2018-11-02)
# 870: Timidria (2018-11-07)
# 871: The Population Council, Inc. (2018-11-09)
# 872: Welthungerhilfe (2018-11-12)
# 873: Aapasi Sahayog Kendra Syangja Nepal (ASK Nepal) (2018-11-14)
# 874: Worldwide Hospice Palliative Care Alliance (2018-11-14)
# 875: International Centre of Insect Physiology and Ecology (icipe) (2018-11-19)
# 876: BDO LLP (2018-11-22)
# 877: Mukisa Foundation (2018-11-23)
# 878: Iraq Foundation (2018-11-26)
# 879: The LO/FTF Council (Ulandssekretariatet) (2018-11-28)
# 880: Transparency International UK (2018-11-28)
# 881: ActionAid Denmark (Mellemfolkeligt Samvirke) (2018-11-29)
# 882: Stichting Deltares (2018-11-30)
# 883: University Twente (2018-12-05)
# 884: International Committee of the Red Cross (ICRC) (2018-12-06)
# 885: Karuna Mission Social Solidarity - KMSS (2018-12-07)
# 886: Iringa Development of Youth, Disabled and Children Care (2018-12-12)
# 887: CHEKA SANA TANZANIA (2018-12-12)
# 888: Babawatoto Centre For Children and Youth (2018-12-12)
# 889: Educate! (2018-12-13)
# 890: Eclosio (2018-12-14)
# 891: British Council (2018-12-14)
# 892: CARE Danmark Fonden for Frivillig Ulandsbistand (2018-12-17)
# 893: Institute for Security Studies (2018-12-17)
# 894: ActionAid Rwanda (2018-12-20)
# 895: PositiveNegatives (2018-12-20)
# 896: Save the Children DK (2018-12-20)
# 897: International Trade Centre (ITC) (2018-12-21)
# 898: Data4Development (2018-12-21)
# 899: Mercy Corps Netherlands (2019-01-02)
# 900: Koninklijk Nederlands Meteorologisch Instituut (2019-01-03)
# 901: The University of Oxford (2019-01-08)
# 902: Mission Øst (2019-01-09)
# 903: Association Centrafricaine de Traduction de la Bible et Alphabetisation (2019-01-11)
# 904: Mercy Corps Global (2019-01-12)
# 905: African Revival (2019-01-15)
# 906: Railway Children Africa (2019-01-16)
# 907: Palliative Care Association of Malawi (2019-01-17)
# 908: Catholic Relief Services (2019-01-18)
# 909: British Asian Trust (2019-01-18)
# 910: David Gordon Memorial Hospital (2019-01-23)
# 911: World Wide Fund for Nature Denmark (2019-01-25)
# 912: AVT-L Association of Victims of Terrorism Lebanon (2019-01-26)
# 913: International Media Support (2019-01-30)
# 914: Sehat Kahani (Community Innovation Hub) (2019-01-31)
# 915: Direcção Provincial de Saúde de Nampula (2019-01-31)
# 916: WWF Sweden (2019-01-31)
# 917: Interpeace (2019-01-31)
# 918: Democratic Governance Facility (2019-02-01)
# 919: Hope for Children (2019-02-06)
# 920: Geneva International Centre for Humanitarian Demining (2019-02-06)
# 921: ADRA Denmark (2019-02-06)
# 922: EDUCATION DEVELOPMENT TRUST - RWANDA (2019-02-06)
# 923: Cowater International Inc (2019-02-06)
# 924: Syria Relief (2019-02-07)
# 925: Danish Family Planning Association (2019-02-07)
# 926: Danmission (2019-02-08)
# 927: Farm Concern International (2019-02-08)
# 928: University Of Zimbabwe (2019-02-10)
# 929: International Fertilizer Development Center (2019-02-12)
# 930: Frontline AIDS (2019-02-14)
# 931: Universiteit Leiden (2019-02-14)
# 932: LTS International Limited (2019-02-14)
# 933: Dansk Missionråds Udviklingsafdeling (2019-02-15)
# 934: Cordaid (2019-02-18)
# 935: Groupe Pivot Santé Population (2019-02-18)
# 936: Danish Red Cross (2019-02-18)
# 937: MDF Global (2019-02-20)
# 938: CARE International Afghanistan (2019-02-20)
# 939: CISU (2019-02-21)
# 940: Global Focus (2019-02-21)
# 941: PlanBørnefonden (2019-02-21)
# 942: OpenNorth (2019-02-21)
# 943: DUF - The Danish Youth Council (2019-02-22)
# 944: NKHOMA MISSION HOSPITAL (2019-02-27)
# 945: Women's Fund Asia (2019-02-27)
# 946: The Fred Hollows Foundation (UK) (2019-02-28)
# 947: African Women's Development Fund (2019-02-28)
# 948: Fundación Fondo Mujeres del Sur (2019-02-28)
# 949: International Indigenous Women Forum (2019-03-01)
# 950: Medecins du Monde France (2019-03-06)
# 951: PATH (2019-03-11)
# 952: Disabled People's Organisations Denmark (2019-03-12)
# 953: Irrawaddy Policy Exchange (2019-03-12)
# 954: Le Monde selon les femmes asbl (2019-03-12)
# 955: Rainforest Alliance (2019-03-12)
# 956: The Global Development Incubator, Inc (2019-03-13)
# 957: We World - GVC Onlus (2019-03-18)
# 958: Niger Delta Stakeholders Initiative for Community Development and Empowerment (2019-03-19)
# 959: The Louis Berger Group Inc. (2019-03-20)
# 960: Stakeholder Democracy Network (2019-03-21)
# 961: Germany - Federal Foreign Office (2019-03-21)

# %%
import iatikit

# get the AsDB publisher
asdb = registry.publishers.find(name='asdb')

activities = asdb.activities

total_c = 0
total_d_e = 0

for activity in activities:  
    values = activity.etree.xpath('transaction[transaction-type/@code="C"]/value/text()')
    total_c += sum([float(v) for v in values])

for activity in activities:  
    values = activity.etree.xpath('transaction[transaction-type/@code="D" or transaction-type/@code="E"]/value/text()')
    total_d_e += sum([float(v) for v in values])

print(total_c)        
print(total_d_e)
# Out:
# 156554932323.78998
# 92602825355.02998

# %%
import iatikit

registry = iatikit.data()

dfid = registry.publishers.find(name='dfid')
sector_category = iatikit.Sector(311, 2)  # Agriculture

ag_acts = dfid.activities.where(
    actual_start__lte='2017-12-31',  # started before 2018
    actual_end__gte='2017-01-01',  # ended after 2016
    sector__in=sector_category,
)
print('DFID had {:,} agricultural activities running during 2017.'.format(
    len(ag_acts)))
# Out:
# DFID had 201 agricultural activities running during 2017.

# %%
transaction_types = ['D', 'E', '3', '4']
' or '.join(['transaction-type/@code="{transaction_type}"'.format(
        transaction_type=transaction_type,
    ) for transaction_type in transaction_types])
# Out:
# 'transaction-type/@code="D" or transaction-type/@code="E" or transaction-type/@code="3" or transaction-type/@code="4"'

# %%
import iatikit
from collections import defaultdict

registry = iatikit.data()

def total_transactions(transaction_name, org_name, year):
    if transaction_name == 'commitments':
        transaction_types = ['C', '2']
    elif transaction_name == 'spend':
        transaction_types = ['D', 'E', '3', '4']
    else:
        raise Exception(f'Unknown transaction name: {transaction_name}')
    org = registry.publishers.find(name=org_name)
    activities = org.activities

    total = defaultdict(float)

    type_str = ' or '.join([f'transaction-type/@code="{transaction_type}"'
                            for transaction_type in transaction_types])
    
    path = f'transaction[{type_str}]' + \
           f'[number(translate(transaction-date/@iso-date, "-", "")) >= {year}0101 ' + \
           f'and number(translate(transaction-date/@iso-date, "-", "")) < {year+1}0101]' + \
           f'/value'
    for activity in activities:
        values = activity.etree.xpath(path)
        default_currency = activity.etree.get('default-currency')
        for value in values:
            currency = value.get('currency') or default_currency
            total[currency] += float(value.text)

    print(f'Sum of {transaction_name} for {org_name} in {year}:')
    if total == {}:
        print('  No transactions of that type were found')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': None,
            'value': None,
        }]
    else:
        for currency, value in total.items():
            print(f'  {currency} {value:,.0f}')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': currency,
            'value': value,
        } for currency, value in total.items()]
    
    return out

# %%
import csv
fieldnames = ['org_name', 'year', 'transaction_type', 'currency', 'value']

org_names = [
    'asdb',
    'undp',
    'dfid',
    'afdb',
    'millenniumchallenge',
    'worldbank',
    'iadb',
    'gac-amc',
    'unicef',
    'ec-echo',
    'ec-near',
    'gavi',
    'theglobalfund',
    'sida',
    'minbuza_nl',
    'usaid',
    'ec-devco',
    'be-dgd',
    'unitedstates',
    'bmz',
    'ausgov',
    'ebrd',
    'eib',
    'finland_mfa',
    'ifcwbg',
    'sdc_ch',
    'danida',
    'bmgf',
    'france',
    'afd',
    'aics',
    'norad',
    'irishaid',
    'jica',
    'odakorea',
    'maec',
    'fco',
    'unocha',
    'mfat',
    'mofa-jpn',

]
with open('output.csv', 'w') as handler:
    writer = csv.DictWriter(handler, fieldnames=fieldnames)
    writer.writeheader()
    for org_name in org_names:
        for transaction_name in ['commitments', 'spend']:
            for year in [2017]:
                    output = total_transactions(transaction_name, org_name, year)
                    for o in output:
                        writer.writerow(o)
# Out:
# Sum of commitments for asdb in 2017:
#   USD 16,890,374,000
# Sum of spend for asdb in 2017:
#   USD 10,338,893,286
# Sum of commitments for undp in 2017:
#   No transactions of that type were found
# Sum of spend for undp in 2017:
#   USD 4,181,721,365
# Sum of commitments for dfid in 2017:
#   GBP 12,535,833,806
# Sum of spend for dfid in 2017:
#   GBP 8,800,304,807
# Sum of commitments for afdb in 2017:
#   XDR 5,877,483,644
# Sum of spend for afdb in 2017:
#   XDR 4,832,476,083
# Sum of commitments for millenniumchallenge in 2017:
#   USD 1,052,824,067
# Sum of spend for millenniumchallenge in 2017:
#   USD 719,539,661
# WARNING:root:Dataset "worldbank-289" XML is invalid
# WARNING:root:Dataset "worldbank-298" XML is invalid
# WARNING:root:Dataset "worldbank-389" XML is invalid
# WARNING:root:Dataset "worldbank-619" XML is invalid
# WARNING:root:Dataset "worldbank-679" XML is invalid
# WARNING:root:Dataset "worldbank-889" XML is invalid
# WARNING:root:Dataset "worldbank-89" XML is invalid
# WARNING:root:Dataset "worldbank-998" XML is invalid
# WARNING:root:Dataset "worldbank-af" XML is invalid
# WARNING:root:Dataset "worldbank-ag" XML is invalid
# WARNING:root:Dataset "worldbank-al" XML is invalid
# WARNING:root:Dataset "worldbank-am" XML is invalid
# WARNING:root:Dataset "worldbank-ao" XML is invalid
# WARNING:root:Dataset "worldbank-ar" XML is invalid
# WARNING:root:Dataset "worldbank-az" XML is invalid
# WARNING:root:Dataset "worldbank-ba" XML is invalid
# WARNING:root:Dataset "worldbank-bb" XML is invalid
# WARNING:root:Dataset "worldbank-bd" XML is invalid
# WARNING:root:Dataset "worldbank-bf" XML is invalid
# WARNING:root:Dataset "worldbank-bg" XML is invalid
# WARNING:root:Dataset "worldbank-bi" XML is invalid
# WARNING:root:Dataset "worldbank-bj" XML is invalid
# WARNING:root:Dataset "worldbank-bo" XML is invalid
# WARNING:root:Dataset "worldbank-br" XML is invalid
# WARNING:root:Dataset "worldbank-bt" XML is invalid
# WARNING:root:Dataset "worldbank-bw" XML is invalid
# WARNING:root:Dataset "worldbank-by" XML is invalid
# WARNING:root:Dataset "worldbank-bz" XML is invalid
# WARNING:root:Dataset "worldbank-cd" XML is invalid
# WARNING:root:Dataset "worldbank-cf" XML is invalid
# WARNING:root:Dataset "worldbank-cg" XML is invalid
# WARNING:root:Dataset "worldbank-ci" XML is invalid
# WARNING:root:Dataset "worldbank-cl" XML is invalid
# WARNING:root:Dataset "worldbank-cm" XML is invalid
# WARNING:root:Dataset "worldbank-cn" XML is invalid
# WARNING:root:Dataset "worldbank-co" XML is invalid
# WARNING:root:Dataset "worldbank-cr" XML is invalid
# WARNING:root:Dataset "worldbank-cv" XML is invalid
# WARNING:root:Dataset "worldbank-dj" XML is invalid
# WARNING:root:Dataset "worldbank-dm" XML is invalid
# WARNING:root:Dataset "worldbank-do" XML is invalid
# WARNING:root:Dataset "worldbank-ec" XML is invalid
# WARNING:root:Dataset "worldbank-eg" XML is invalid
# WARNING:root:Dataset "worldbank-et" XML is invalid
# WARNING:root:Dataset "worldbank-fj" XML is invalid
# WARNING:root:Dataset "worldbank-fm" XML is invalid
# WARNING:root:Dataset "worldbank-ga" XML is invalid
# WARNING:root:Dataset "worldbank-gd" XML is invalid
# WARNING:root:Dataset "worldbank-ge" XML is invalid
# WARNING:root:Dataset "worldbank-gh" XML is invalid
# WARNING:root:Dataset "worldbank-gm" XML is invalid
# WARNING:root:Dataset "worldbank-gn" XML is invalid
# WARNING:root:Dataset "worldbank-gt" XML is invalid
# WARNING:root:Dataset "worldbank-gw" XML is invalid
# WARNING:root:Dataset "worldbank-gy" XML is invalid
# WARNING:root:Dataset "worldbank-hn" XML is invalid
# WARNING:root:Dataset "worldbank-hr" XML is invalid
# WARNING:root:Dataset "worldbank-ht" XML is invalid
# WARNING:root:Dataset "worldbank-id" XML is invalid
# WARNING:root:Dataset "worldbank-in" XML is invalid
# WARNING:root:Dataset "worldbank-iq" XML is invalid
# WARNING:root:Dataset "worldbank-ir" XML is invalid
# WARNING:root:Dataset "worldbank-jm" XML is invalid
# WARNING:root:Dataset "worldbank-jo" XML is invalid
# WARNING:root:Dataset "worldbank-ke" XML is invalid
# WARNING:root:Dataset "worldbank-kg" XML is invalid
# WARNING:root:Dataset "worldbank-kh" XML is invalid
# WARNING:root:Dataset "worldbank-ki" XML is invalid
# WARNING:root:Dataset "worldbank-km" XML is invalid
# WARNING:root:Dataset "worldbank-kz" XML is invalid
# WARNING:root:Dataset "worldbank-la" XML is invalid
# WARNING:root:Dataset "worldbank-lb" XML is invalid
# WARNING:root:Dataset "worldbank-lc" XML is invalid
# WARNING:root:Dataset "worldbank-lk" XML is invalid
# WARNING:root:Dataset "worldbank-lr" XML is invalid
# WARNING:root:Dataset "worldbank-ls" XML is invalid
# WARNING:root:Dataset "worldbank-ma" XML is invalid
# WARNING:root:Dataset "worldbank-md" XML is invalid
# WARNING:root:Dataset "worldbank-me" XML is invalid
# WARNING:root:Dataset "worldbank-mg" XML is invalid
# WARNING:root:Dataset "worldbank-mh" XML is invalid
# WARNING:root:Dataset "worldbank-mk" XML is invalid
# WARNING:root:Dataset "worldbank-ml" XML is invalid
# WARNING:root:Dataset "worldbank-mm" XML is invalid
# WARNING:root:Dataset "worldbank-mn" XML is invalid
# WARNING:root:Dataset "worldbank-mr" XML is invalid
# WARNING:root:Dataset "worldbank-mu" XML is invalid
# WARNING:root:Dataset "worldbank-mv" XML is invalid
# WARNING:root:Dataset "worldbank-mw" XML is invalid
# WARNING:root:Dataset "worldbank-mx" XML is invalid
# WARNING:root:Dataset "worldbank-mz" XML is invalid
# WARNING:root:Dataset "worldbank-ne" XML is invalid
# WARNING:root:Dataset "worldbank-ng" XML is invalid
# WARNING:root:Dataset "worldbank-ni" XML is invalid
# WARNING:root:Dataset "worldbank-np" XML is invalid
# WARNING:root:Dataset "worldbank-pa" XML is invalid
# WARNING:root:Dataset "worldbank-pe" XML is invalid
# WARNING:root:Dataset "worldbank-pg" XML is invalid
# WARNING:root:Dataset "worldbank-ph" XML is invalid
# WARNING:root:Dataset "worldbank-pk" XML is invalid
# WARNING:root:Dataset "worldbank-pl" XML is invalid
# WARNING:root:Dataset "worldbank-py" XML is invalid
# WARNING:root:Dataset "worldbank-ro" XML is invalid
# WARNING:root:Dataset "worldbank-rs" XML is invalid
# WARNING:root:Dataset "worldbank-ru" XML is invalid
# WARNING:root:Dataset "worldbank-rw" XML is invalid
# WARNING:root:Dataset "worldbank-sb" XML is invalid
# WARNING:root:Dataset "worldbank-sc" XML is invalid
# WARNING:root:Dataset "worldbank-sl" XML is invalid
# WARNING:root:Dataset "worldbank-sn" XML is invalid
# WARNING:root:Dataset "worldbank-so" XML is invalid
# WARNING:root:Dataset "worldbank-sr" XML is invalid
# WARNING:root:Dataset "worldbank-ss" XML is invalid
# WARNING:root:Dataset "worldbank-st" XML is invalid
# WARNING:root:Dataset "worldbank-sv" XML is invalid
# WARNING:root:Dataset "worldbank-sz" XML is invalid
# WARNING:root:Dataset "worldbank-td" XML is invalid
# WARNING:root:Dataset "worldbank-tg" XML is invalid
# WARNING:root:Dataset "worldbank-th" XML is invalid
# WARNING:root:Dataset "worldbank-tj" XML is invalid
# WARNING:root:Dataset "worldbank-tl" XML is invalid
# WARNING:root:Dataset "worldbank-tn" XML is invalid
# WARNING:root:Dataset "worldbank-to" XML is invalid
# WARNING:root:Dataset "worldbank-tr" XML is invalid
# WARNING:root:Dataset "worldbank-tv" XML is invalid
# WARNING:root:Dataset "worldbank-tz" XML is invalid
# WARNING:root:Dataset "worldbank-ua" XML is invalid
# WARNING:root:Dataset "worldbank-ug" XML is invalid
# WARNING:root:Dataset "worldbank-uy" XML is invalid
# WARNING:root:Dataset "worldbank-uz" XML is invalid
# WARNING:root:Dataset "worldbank-vc" XML is invalid
# WARNING:root:Dataset "worldbank-vn" XML is invalid
# WARNING:root:Dataset "worldbank-vu" XML is invalid
# WARNING:root:Dataset "worldbank-ws" XML is invalid
# WARNING:root:Dataset "worldbank-xk" XML is invalid
# WARNING:root:Dataset "worldbank-ye" XML is invalid
# WARNING:root:Dataset "worldbank-za" XML is invalid
# WARNING:root:Dataset "worldbank-zm" XML is invalid
# WARNING:root:Dataset "worldbank-289" XML is invalid
# WARNING:root:Dataset "worldbank-298" XML is invalid
# WARNING:root:Dataset "worldbank-389" XML is invalid
# WARNING:root:Dataset "worldbank-619" XML is invalid
# WARNING:root:Dataset "worldbank-679" XML is invalid
# WARNING:root:Dataset "worldbank-889" XML is invalid
# WARNING:root:Dataset "worldbank-89" XML is invalid
# WARNING:root:Dataset "worldbank-998" XML is invalid
# WARNING:root:Dataset "worldbank-af" XML is invalid
# WARNING:root:Dataset "worldbank-ag" XML is invalid
# WARNING:root:Dataset "worldbank-al" XML is invalid
# Sum of commitments for worldbank in 2017:
#   No transactions of that type were found
# WARNING:root:Dataset "worldbank-am" XML is invalid
# WARNING:root:Dataset "worldbank-ao" XML is invalid
# WARNING:root:Dataset "worldbank-ar" XML is invalid
# WARNING:root:Dataset "worldbank-az" XML is invalid
# WARNING:root:Dataset "worldbank-ba" XML is invalid
# WARNING:root:Dataset "worldbank-bb" XML is invalid
# WARNING:root:Dataset "worldbank-bd" XML is invalid
# WARNING:root:Dataset "worldbank-bf" XML is invalid
# WARNING:root:Dataset "worldbank-bg" XML is invalid
# WARNING:root:Dataset "worldbank-bi" XML is invalid
# WARNING:root:Dataset "worldbank-bj" XML is invalid
# WARNING:root:Dataset "worldbank-bo" XML is invalid
# WARNING:root:Dataset "worldbank-br" XML is invalid
# WARNING:root:Dataset "worldbank-bt" XML is invalid
# WARNING:root:Dataset "worldbank-bw" XML is invalid
# WARNING:root:Dataset "worldbank-by" XML is invalid
# WARNING:root:Dataset "worldbank-bz" XML is invalid
# WARNING:root:Dataset "worldbank-cd" XML is invalid
# WARNING:root:Dataset "worldbank-cf" XML is invalid
# WARNING:root:Dataset "worldbank-cg" XML is invalid
# WARNING:root:Dataset "worldbank-ci" XML is invalid
# WARNING:root:Dataset "worldbank-cl" XML is invalid
# WARNING:root:Dataset "worldbank-cm" XML is invalid
# WARNING:root:Dataset "worldbank-cn" XML is invalid
# WARNING:root:Dataset "worldbank-co" XML is invalid
# WARNING:root:Dataset "worldbank-cr" XML is invalid
# WARNING:root:Dataset "worldbank-cv" XML is invalid
# WARNING:root:Dataset "worldbank-dj" XML is invalid
# WARNING:root:Dataset "worldbank-dm" XML is invalid
# WARNING:root:Dataset "worldbank-do" XML is invalid
# WARNING:root:Dataset "worldbank-ec" XML is invalid
# WARNING:root:Dataset "worldbank-eg" XML is invalid
# WARNING:root:Dataset "worldbank-et" XML is invalid
# WARNING:root:Dataset "worldbank-fj" XML is invalid
# WARNING:root:Dataset "worldbank-fm" XML is invalid
# WARNING:root:Dataset "worldbank-ga" XML is invalid
# WARNING:root:Dataset "worldbank-gd" XML is invalid
# WARNING:root:Dataset "worldbank-ge" XML is invalid
# WARNING:root:Dataset "worldbank-gh" XML is invalid
# WARNING:root:Dataset "worldbank-gm" XML is invalid
# WARNING:root:Dataset "worldbank-gn" XML is invalid
# WARNING:root:Dataset "worldbank-gt" XML is invalid
# WARNING:root:Dataset "worldbank-gw" XML is invalid
# WARNING:root:Dataset "worldbank-gy" XML is invalid
# WARNING:root:Dataset "worldbank-hn" XML is invalid
# WARNING:root:Dataset "worldbank-hr" XML is invalid
# WARNING:root:Dataset "worldbank-ht" XML is invalid
# WARNING:root:Dataset "worldbank-id" XML is invalid
# WARNING:root:Dataset "worldbank-in" XML is invalid
# WARNING:root:Dataset "worldbank-iq" XML is invalid
# WARNING:root:Dataset "worldbank-ir" XML is invalid
# WARNING:root:Dataset "worldbank-jm" XML is invalid
# WARNING:root:Dataset "worldbank-jo" XML is invalid
# WARNING:root:Dataset "worldbank-ke" XML is invalid
# WARNING:root:Dataset "worldbank-kg" XML is invalid
# WARNING:root:Dataset "worldbank-kh" XML is invalid
# WARNING:root:Dataset "worldbank-ki" XML is invalid
# WARNING:root:Dataset "worldbank-km" XML is invalid
# WARNING:root:Dataset "worldbank-kz" XML is invalid
# WARNING:root:Dataset "worldbank-la" XML is invalid
# WARNING:root:Dataset "worldbank-lb" XML is invalid
# WARNING:root:Dataset "worldbank-lc" XML is invalid
# WARNING:root:Dataset "worldbank-lk" XML is invalid
# WARNING:root:Dataset "worldbank-lr" XML is invalid
# WARNING:root:Dataset "worldbank-ls" XML is invalid
# WARNING:root:Dataset "worldbank-ma" XML is invalid
# WARNING:root:Dataset "worldbank-md" XML is invalid
# WARNING:root:Dataset "worldbank-me" XML is invalid
# WARNING:root:Dataset "worldbank-mg" XML is invalid
# WARNING:root:Dataset "worldbank-mh" XML is invalid
# WARNING:root:Dataset "worldbank-mk" XML is invalid
# WARNING:root:Dataset "worldbank-ml" XML is invalid
# WARNING:root:Dataset "worldbank-mm" XML is invalid
# WARNING:root:Dataset "worldbank-mn" XML is invalid
# WARNING:root:Dataset "worldbank-mr" XML is invalid
# WARNING:root:Dataset "worldbank-mu" XML is invalid
# WARNING:root:Dataset "worldbank-mv" XML is invalid
# WARNING:root:Dataset "worldbank-mw" XML is invalid
# WARNING:root:Dataset "worldbank-mx" XML is invalid
# WARNING:root:Dataset "worldbank-mz" XML is invalid
# WARNING:root:Dataset "worldbank-ne" XML is invalid
# WARNING:root:Dataset "worldbank-ng" XML is invalid
# WARNING:root:Dataset "worldbank-ni" XML is invalid
# WARNING:root:Dataset "worldbank-np" XML is invalid
# WARNING:root:Dataset "worldbank-pa" XML is invalid
# WARNING:root:Dataset "worldbank-pe" XML is invalid
# WARNING:root:Dataset "worldbank-pg" XML is invalid
# WARNING:root:Dataset "worldbank-ph" XML is invalid
# WARNING:root:Dataset "worldbank-pk" XML is invalid
# WARNING:root:Dataset "worldbank-pl" XML is invalid
# WARNING:root:Dataset "worldbank-py" XML is invalid
# WARNING:root:Dataset "worldbank-ro" XML is invalid
# WARNING:root:Dataset "worldbank-rs" XML is invalid
# WARNING:root:Dataset "worldbank-ru" XML is invalid
# WARNING:root:Dataset "worldbank-rw" XML is invalid
# WARNING:root:Dataset "worldbank-sb" XML is invalid
# WARNING:root:Dataset "worldbank-sc" XML is invalid
# WARNING:root:Dataset "worldbank-sl" XML is invalid
# WARNING:root:Dataset "worldbank-sn" XML is invalid
# WARNING:root:Dataset "worldbank-so" XML is invalid
# WARNING:root:Dataset "worldbank-sr" XML is invalid
# WARNING:root:Dataset "worldbank-ss" XML is invalid
# WARNING:root:Dataset "worldbank-st" XML is invalid
# WARNING:root:Dataset "worldbank-sv" XML is invalid
# WARNING:root:Dataset "worldbank-sz" XML is invalid
# WARNING:root:Dataset "worldbank-td" XML is invalid
# WARNING:root:Dataset "worldbank-tg" XML is invalid
# WARNING:root:Dataset "worldbank-th" XML is invalid
# WARNING:root:Dataset "worldbank-tj" XML is invalid
# WARNING:root:Dataset "worldbank-tl" XML is invalid
# WARNING:root:Dataset "worldbank-tn" XML is invalid
# WARNING:root:Dataset "worldbank-to" XML is invalid
# WARNING:root:Dataset "worldbank-tr" XML is invalid
# WARNING:root:Dataset "worldbank-tv" XML is invalid
# WARNING:root:Dataset "worldbank-tz" XML is invalid
# WARNING:root:Dataset "worldbank-ua" XML is invalid
# WARNING:root:Dataset "worldbank-ug" XML is invalid
# WARNING:root:Dataset "worldbank-uy" XML is invalid
# WARNING:root:Dataset "worldbank-uz" XML is invalid
# WARNING:root:Dataset "worldbank-vc" XML is invalid
# WARNING:root:Dataset "worldbank-vn" XML is invalid
# WARNING:root:Dataset "worldbank-vu" XML is invalid
# WARNING:root:Dataset "worldbank-ws" XML is invalid
# WARNING:root:Dataset "worldbank-xk" XML is invalid
# WARNING:root:Dataset "worldbank-ye" XML is invalid
# WARNING:root:Dataset "worldbank-za" XML is invalid
# WARNING:root:Dataset "worldbank-zm" XML is invalid
# Sum of spend for worldbank in 2017:
#   No transactions of that type were found
# Sum of commitments for iadb in 2017:
#   USD 10,154,653,279
# Sum of spend for iadb in 2017:
#   USD 8,784,092,441
# Sum of commitments for gac-amc in 2017:
#   CAD 2,963,636,803
# Sum of spend for gac-amc in 2017:
#   CAD 3,125,954,154
# Sum of commitments for unicef in 2017:
#   USD 5,042,334,671
# Sum of spend for unicef in 2017:
#   USD 5,438,421,271
# Sum of commitments for ec-echo in 2017:
#   EUR 2,405,149,113
# Sum of spend for ec-echo in 2017:
#   EUR 2,260,820,545
# Sum of commitments for ec-near in 2017:
#   EUR 3,846,294,231
# WARNING:root:Dataset "gavi-af" XML is invalid
# Sum of spend for ec-near in 2017:
#   EUR 3,248,804,728
# WARNING:root:Dataset "gavi-af" XML is invalid
# Sum of commitments for gavi in 2017:
#   USD 1,123,257,705
# Sum of spend for gavi in 2017:
#   USD 1,270,382,406
# Sum of commitments for theglobalfund in 2017:
#   USD 0
# Sum of spend for theglobalfund in 2017:
#   USD 0
# WARNING:root:Dataset "sida-hum" XML is invalid
# Sum of commitments for sida in 2017:
#   USD 4,080,436,794
# WARNING:root:Dataset "sida-hum" XML is invalid
# Sum of spend for sida in 2017:
#   USD 5,134,475,083
# Sum of commitments for minbuza_nl in 2017:
#   EUR 1,964,490,524
# WARNING:root:Dataset "usaid-289" XML is invalid
# Sum of spend for minbuza_nl in 2017:
#   EUR 2,994,057,226
# WARNING:root:Dataset "usaid-289" XML is invalid
# Sum of commitments for usaid in 2017:
#   USD 19,893,630,845
# Sum of spend for usaid in 2017:
#   USD 19,481,215,652
# Sum of commitments for ec-devco in 2017:
#   EUR 10,064,666,661
# Sum of spend for ec-devco in 2017:
#   EUR 6,755,800,150
# Sum of commitments for be-dgd in 2017:
#   EUR 4,363,507,187
# Sum of spend for be-dgd in 2017:
#   EUR 1,606,519,696
# WARNING:root:Dataset "unitedstates-africa_regional" XML is invalid
# WARNING:root:Dataset "unitedstates-america_regional" XML is invalid
# WARNING:root:Dataset "unitedstates-central_asia_regional" XML is invalid
# Sum of commitments for unitedstates in 2017:
#   USD 6,777,986,475
# WARNING:root:Dataset "unitedstates-africa_regional" XML is invalid
# WARNING:root:Dataset "unitedstates-america_regional" XML is invalid
# WARNING:root:Dataset "unitedstates-central_asia_regional" XML is invalid
# Sum of spend for unitedstates in 2017:
#   USD 9,358,432,508
# Sum of commitments for bmz in 2017:
#   EUR 18,304,533,867
# Sum of spend for bmz in 2017:
#   EUR 10,331,592,753
# WARNING:root:Dataset "ausgov-189" XML is invalid
# WARNING:root:Dataset "ausgov-389" XML is invalid
# WARNING:root:Dataset "ausgov-189" XML is invalid
# WARNING:root:Dataset "ausgov-389" XML is invalid
# Sum of commitments for ausgov in 2017:
#   AUD 3,846,024,863
# Sum of spend for ausgov in 2017:
#   AUD 3,641,317,483
# Sum of commitments for ebrd in 2017:
#   EUR 6,622,548,855
# Sum of spend for ebrd in 2017:
#   EUR 1,711,649,889
# Sum of commitments for eib in 2017:
#   EUR 7,313,023,062
#   USD 4,779,003,500
# Sum of spend for eib in 2017:
#   No transactions of that type were found
# Sum of commitments for finland_mfa in 2017:
#   EUR 858,351,783
# Sum of spend for finland_mfa in 2017:
#   EUR 930,086,910
# Sum of commitments for ifcwbg in 2017:
#   USD 11,869,770,000
# Sum of spend for ifcwbg in 2017:
#   No transactions of that type were found
# Sum of commitments for sdc_ch in 2017:
#   CHF 2,802,629,282
# Sum of spend for sdc_ch in 2017:
#   CHF 1,501,440,637
# Sum of commitments for danida in 2017:
#   DKK 10,372,390,972
# Sum of spend for danida in 2017:
#   DKK 16,967,581,989
# Sum of commitments for bmgf in 2017:
#   USD 4,754,137,121
# Sum of spend for bmgf in 2017:
#   USD 3,829,917,690
# WARNING:root:@version attribute is not declared. Assuming "1.01".
# WARNING:root:Dataset "france-centrale2" XML is invalid
# Sum of commitments for france in 2017:
#   EUR 41,125,281
# WARNING:root:@version attribute is not declared. Assuming "1.01".
# WARNING:root:Dataset "france-centrale2" XML is invalid
# Sum of spend for france in 2017:
#   EUR 3,830,415
# Sum of commitments for afd in 2017:
#   No transactions of that type were found
# Sum of spend for afd in 2017:
#   EUR 1,261,072,185
# WARNING:root:Dataset "aics-089" XML is invalid
# WARNING:root:Dataset "aics-089" XML is invalid
# Sum of commitments for aics in 2017:
#   EUR 998,552,640
# Sum of spend for aics in 2017:
#   EUR 448,070,449
# Sum of commitments for norad in 2017:
#   NOK 34,891,365,967
# Sum of spend for norad in 2017:
#   NOK 34,132,387,252
# Sum of commitments for irishaid in 2017:
#   No transactions of that type were found
# WARNING:root:Dataset "jica-088_2013" XML is invalid
# Sum of spend for irishaid in 2017:
#   EUR 207,870,298
# WARNING:root:Dataset "jica-088_2014" XML is invalid
# WARNING:root:Dataset "jica-089_2013" XML is invalid
# WARNING:root:Dataset "jica-089_2014" XML is invalid
# WARNING:root:Dataset "jica-089_2015" XML is invalid
# WARNING:root:Dataset "jica-189_2013" XML is invalid
# WARNING:root:Dataset "jica-189_2014" XML is invalid
# WARNING:root:Dataset "jica-189_2015" XML is invalid
# WARNING:root:Dataset "jica-289_2013" XML is invalid
# WARNING:root:Dataset "jica-289_2014" XML is invalid
# WARNING:root:Dataset "jica-289_2015" XML is invalid
# WARNING:root:Dataset "jica-380_2013" XML is invalid
# WARNING:root:Dataset "jica-380_2014" XML is invalid
# WARNING:root:Dataset "jica-380_2015" XML is invalid
# WARNING:root:Dataset "jica-389_2013" XML is invalid
# WARNING:root:Dataset "jica-389_2014" XML is invalid
# WARNING:root:Dataset "jica-389_2015" XML is invalid
# WARNING:root:Dataset "jica-489_2013" XML is invalid
# WARNING:root:Dataset "jica-489_2014" XML is invalid
# WARNING:root:Dataset "jica-489_2015" XML is invalid
# WARNING:root:Dataset "jica-589_2013" XML is invalid
# WARNING:root:Dataset "jica-589_2014" XML is invalid
# WARNING:root:Dataset "jica-589_2015" XML is invalid
# WARNING:root:Dataset "jica-619_2013" XML is invalid
# WARNING:root:Dataset "jica-619_2014" XML is invalid
# WARNING:root:Dataset "jica-619_2015" XML is invalid
# WARNING:root:Dataset "jica-679_2013" XML is invalid
# WARNING:root:Dataset "jica-679_2014" XML is invalid
# WARNING:root:Dataset "jica-679_2015" XML is invalid
# WARNING:root:Dataset "jica-789_2013" XML is invalid
# WARNING:root:Dataset "jica-789_2014" XML is invalid
# WARNING:root:Dataset "jica-789_2015" XML is invalid
# WARNING:root:Dataset "jica-889_2013" XML is invalid
# WARNING:root:Dataset "jica-889_2014" XML is invalid
# WARNING:root:Dataset "jica-889_2015" XML is invalid
# WARNING:root:Dataset "jica-998_2013" XML is invalid
# WARNING:root:Dataset "jica-998_2014" XML is invalid
# WARNING:root:Dataset "jica-998_2015" XML is invalid
# WARNING:root:Dataset "jica-grant_2012" XML is invalid
# WARNING:root:Dataset "jica-loans_2013" XML is invalid
# WARNING:root:Dataset "jica-088_2013" XML is invalid
# WARNING:root:Dataset "jica-088_2014" XML is invalid
# WARNING:root:Dataset "jica-089_2013" XML is invalid
# WARNING:root:Dataset "jica-089_2014" XML is invalid
# WARNING:root:Dataset "jica-089_2015" XML is invalid
# WARNING:root:Dataset "jica-189_2013" XML is invalid
# WARNING:root:Dataset "jica-189_2014" XML is invalid
# WARNING:root:Dataset "jica-189_2015" XML is invalid
# WARNING:root:Dataset "jica-289_2013" XML is invalid
# WARNING:root:Dataset "jica-289_2014" XML is invalid
# WARNING:root:Dataset "jica-289_2015" XML is invalid
# WARNING:root:Dataset "jica-380_2013" XML is invalid
# WARNING:root:Dataset "jica-380_2014" XML is invalid
# WARNING:root:Dataset "jica-380_2015" XML is invalid
# WARNING:root:Dataset "jica-389_2013" XML is invalid
# WARNING:root:Dataset "jica-389_2014" XML is invalid
# WARNING:root:Dataset "jica-389_2015" XML is invalid
# WARNING:root:Dataset "jica-489_2013" XML is invalid
# WARNING:root:Dataset "jica-489_2014" XML is invalid
# WARNING:root:Dataset "jica-489_2015" XML is invalid
# WARNING:root:Dataset "jica-589_2013" XML is invalid
# WARNING:root:Dataset "jica-589_2014" XML is invalid
# WARNING:root:Dataset "jica-589_2015" XML is invalid
# WARNING:root:Dataset "jica-619_2013" XML is invalid
# WARNING:root:Dataset "jica-619_2014" XML is invalid
# WARNING:root:Dataset "jica-619_2015" XML is invalid
# WARNING:root:Dataset "jica-679_2013" XML is invalid
# WARNING:root:Dataset "jica-679_2014" XML is invalid
# WARNING:root:Dataset "jica-679_2015" XML is invalid
# WARNING:root:Dataset "jica-789_2013" XML is invalid
# WARNING:root:Dataset "jica-789_2014" XML is invalid
# WARNING:root:Dataset "jica-789_2015" XML is invalid
# WARNING:root:Dataset "jica-889_2013" XML is invalid
# WARNING:root:Dataset "jica-889_2014" XML is invalid
# Sum of commitments for jica in 2017:
#   No transactions of that type were found
# WARNING:root:Dataset "jica-889_2015" XML is invalid
# WARNING:root:Dataset "jica-998_2013" XML is invalid
# WARNING:root:Dataset "jica-998_2014" XML is invalid
# WARNING:root:Dataset "jica-998_2015" XML is invalid
# WARNING:root:Dataset "jica-grant_2012" XML is invalid
# WARNING:root:Dataset "jica-loans_2013" XML is invalid
# Sum of spend for jica in 2017:
#   No transactions of that type were found
# Sum of commitments for odakorea in 2017:
#   KRW 2,904,589,990
# Sum of spend for odakorea in 2017:
#   No transactions of that type were found
# Sum of commitments for maec in 2017:
#   No transactions of that type were found
# Sum of spend for maec in 2017:
#   No transactions of that type were found
# Sum of commitments for fco in 2017:
#   No transactions of that type were found
# Sum of spend for fco in 2017:
#   GBP 786,802,095
# Sum of commitments for unocha in 2017:
#   No transactions of that type were found
# Sum of spend for unocha in 2017:
#   No transactions of that type were found
# Sum of commitments for mfat in 2017:
#   No transactions of that type were found
# Sum of spend for mfat in 2017:
#   NZD 90,878,890
# Sum of commitments for mofa-jpn in 2017:
#   No transactions of that type were found
# Sum of spend for mofa-jpn in 2017:
#   No transactions of that type were found

# %%
import iatikit
from collections import defaultdict

registry = iatikit.data()

def total_transactions(transaction_name, org_name, year):
    if transaction_name == 'commitments':
        transaction_types = ['C', '2']
    elif transaction_name == 'spend':
        transaction_types = ['D', 'E', '3', '4']
    else:
        raise Exception(f'Unknown transaction name: {transaction_name}')
    org = registry.publishers.find(name=org_name)
    activities = org.activities

    total = defaultdict(float)

    type_str = ' or '.join([f'transaction-type/@code="{transaction_type}"'
                            for transaction_type in transaction_types])
    
    path = f'transaction[{type_str}]' + \
           f'[number(translate(transaction-date/@iso-date, "-", "")) >= {year}0406 ' + \
           f'and number(translate(transaction-date/@iso-date, "-", "")) < {year+1}0406]' + \
           f'/value'
    for activity in activities:
        values = activity.etree.xpath(path)
        default_currency = activity.etree.get('default-currency')
        for value in values:
            currency = value.get('currency') or default_currency
            total[currency] += float(value.text)

    print(f'Sum of {transaction_name} for {org_name} in {year}:')
    if total == {}:
        print('  No transactions of that type were found')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': None,
            'value': None,
        }]
    else:
        for currency, value in total.items():
            print(f'  {currency} {value:,.0f}')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': currency,
            'value': value,
        } for currency, value in total.items()]
    
    return out

# %%
import csv
fieldnames = ['org_name', 'year', 'transaction_type', 'currency', 'value']

org_names = [
    'beis',
    'fco',
    'defra_transparency',
    'dwp',
    'dhsc',
    'homeoffice',
    'ukmod',
    'dcms',
    'dfid',
    'dfe'
]
with open('output.csv', 'w') as handler:
    writer = csv.DictWriter(handler, fieldnames=fieldnames)
    writer.writeheader()
    for org_name in org_names:
        for transaction_name in ['commitments', 'spend']:
            for year in [2019, 2018, 2017]:
                    output = total_transactions(transaction_name, org_name, year)
                    for o in output:
                        writer.writerow(o)
# Out:
# Sum of commitments for beis in 2019:
#   No transactions of that type were found
# Sum of commitments for beis in 2018:
#   GBP 322,100,000
# Sum of commitments for beis in 2017:
#   GBP 494,983,801
# Sum of spend for beis in 2019:
#   GBP 80,834,005
#   USD 4,000,000
# Sum of spend for beis in 2018:
#   GBP 368,113,119
#   USD 8,163,335
# Sum of spend for beis in 2017:
#   GBP 412,480,683
#   USD 9,875,000
# Sum of commitments for fco in 2019:
#   No transactions of that type were found
# Sum of commitments for fco in 2018:
#   No transactions of that type were found
# Sum of commitments for fco in 2017:
#   No transactions of that type were found
# Sum of spend for fco in 2019:
#   No transactions of that type were found
# Sum of spend for fco in 2018:
#   GBP 1,042,825,223
# Sum of spend for fco in 2017:
#   GBP 886,569,095
# Sum of commitments for defra_transparency in 2019:
#   GBP 12,257,860
# Sum of commitments for defra_transparency in 2018:
#   GBP 12,742,860
# Sum of commitments for defra_transparency in 2017:
#   GBP 42,000,000
# Sum of spend for defra_transparency in 2019:
#   No transactions of that type were found
# Sum of spend for defra_transparency in 2018:
#   GBP 14,762,752
# Sum of spend for defra_transparency in 2017:
#   GBP 12,302,576
# Sum of commitments for dwp in 2019:
#   No transactions of that type were found
# Sum of commitments for dwp in 2018:
#   No transactions of that type were found
# Sum of commitments for dwp in 2017:
#   No transactions of that type were found
# Sum of spend for dwp in 2019:
#   No transactions of that type were found
# Sum of spend for dwp in 2018:
#   No transactions of that type were found
# Sum of spend for dwp in 2017:
#   No transactions of that type were found
# Sum of commitments for dhsc in 2019:
#   No transactions of that type were found
# Sum of commitments for dhsc in 2018:
#   GBP 111,675,048
# Sum of commitments for dhsc in 2017:
#   GBP 173,085,926
#   EUR 19,000,000
# Sum of spend for dhsc in 2019:
#   GBP 3,650,000
# Sum of spend for dhsc in 2018:
#   GBP 145,429,377
# Sum of spend for dhsc in 2017:
#   GBP 96,653,939
# Sum of commitments for homeoffice in 2019:
#   No transactions of that type were found
# Sum of commitments for homeoffice in 2018:
#   No transactions of that type were found
# Sum of commitments for homeoffice in 2017:
#   No transactions of that type were found
# Sum of spend for homeoffice in 2019:
#   No transactions of that type were found
# Sum of spend for homeoffice in 2018:
#   GBP 175,795,000
# Sum of spend for homeoffice in 2017:
#   GBP 163,505,000
# Sum of commitments for ukmod in 2019:
#   No transactions of that type were found
# Sum of commitments for ukmod in 2018:
#   No transactions of that type were found
# Sum of commitments for ukmod in 2017:
#   No transactions of that type were found
# Sum of spend for ukmod in 2019:
#   No transactions of that type were found
# Sum of spend for ukmod in 2018:
#   GBP 2,181,750
# Sum of spend for ukmod in 2017:
#   GBP 231,203
# Sum of commitments for dcms in 2019:
#   No transactions of that type were found
# Sum of commitments for dcms in 2018:
#   No transactions of that type were found
# Sum of commitments for dcms in 2017:
#   No transactions of that type were found
# Sum of spend for dcms in 2019:
#   No transactions of that type were found
# Sum of spend for dcms in 2018:
#   GBP 11,018,065
# Sum of spend for dcms in 2017:
#   GBP 3,342,023
# Sum of commitments for dfid in 2019:
#   GBP 969,155,585
# Sum of commitments for dfid in 2018:
#   GBP 4,583,063,678
# Sum of commitments for dfid in 2017:
#   GBP 7,707,691,008
# Sum of spend for dfid in 2019:
#   GBP 1,819,738,674
# Sum of spend for dfid in 2018:
#   GBP 9,311,125,736
# Sum of spend for dfid in 2017:
#   GBP 8,956,317,917
# Sum of commitments for dfe in 2019:
#   No transactions of that type were found
# Sum of commitments for dfe in 2018:
#   No transactions of that type were found
# Sum of commitments for dfe in 2017:
#   No transactions of that type were found
# Sum of spend for dfe in 2019:
#   No transactions of that type were found
# Sum of spend for dfe in 2018:
#   No transactions of that type were found
# Sum of spend for dfe in 2017:
#   No transactions of that type were found

# %%
import iatikit
from collections import defaultdict

registry = iatikit.data()

import csv
fieldnames = ['name', 'period-start', 'period-end', 'value', 'currency']

pub_names = [
    'asdb',
    'undp',
    'dfid',
    'afdb',
    'millenniumchallenge',
    'worldbank',
    'iadb',
    'gac-amc',
    'unicef',
    'ec-echo',
    'ec-near',
    'gavi',
    'theglobalfund',
    'sida',
    'minbuza_nl',
    'usaid',
    'ec-devco',
    'be-dgd',
    'unitedstates',
    'bmz',
    'ausgov',
    'ebrd',
    'eib',
    'finland_mfa',
    'ifcwbg',
    'sdc_ch',
    'danida',
    'bmgf',
    'france',
    'afd',
    'aics',
    'norad',
    'irishaid',
    'jica',
    'odakorea',
    'maec',
    'fco',
    'unocha',
    'mfat',
    'mofa-jpn',

]

rows = []

for pub_name in pub_names:
    pub = registry.publishers.get(pub_name)
# print(pub)
    orgs = list(pub.organisations)
    for org in orgs:
        default_currency = org.etree.xpath('@default-currency')
        default_currency = default_currency[0] if default_currency != [] else 'No default_currency provided'
        name = org.etree.xpath('name/narrative/text()')
        name = name[0] if name != [] else 'No name provided'
        totals = org.etree.xpath('total-expenditure')
        for total in totals:
            period_start = total.xpath('period-start/@iso-date')[0]
            period_end = total.xpath('period-end/@iso-date')[0]
            value = total.xpath('value/text()')[0]
            currency = total.xpath('value/@currency')
            currency = currency[0] if currency != [] else default_currency
            rows.append({
                'name': name, 
                'period-start': period_start, 
                'period-end': period_end, 
                'value': value,
                'currency': currency,
            })
            
# print(rows)
            
with open('totalspend.csv', 'w') as handler:
    writer = csv.DictWriter(handler, fieldnames=fieldnames)
    writer.writeheader()
    for row in rows:
        writer.writerow(row)
# Out:
# WARNING:root:Dataset "theglobalfund-org" XML is invalid
# WARNING:root:Dataset "theglobalfund-org" XML is invalid
# WARNING:root:Dataset "sida-org" XML is invalid
# WARNING:root:Dataset "sida-organisation" XML is invalid
# WARNING:root:Dataset "sida-org" XML is invalid
# WARNING:root:Dataset "sida-organisation" XML is invalid
# WARNING:root:Dataset "jica-org" XML is invalid
# WARNING:root:Dataset "jica-org" XML is invalid

# %%
import iatikit
from collections import defaultdict

registry = iatikit.data()

def total_transactions(transaction_name, org_name, year):
    if transaction_name == 'commitments':
        transaction_types = ['C', '2']
    elif transaction_name == 'spend':
        transaction_types = ['D', 'E', '3', '4']
    else:
        raise Exception(f'Unknown transaction name: {transaction_name}')
    org = registry.publishers.find(name=org_name)
    activities = org.activities

    total = defaultdict(float)

    type_str = ' or '.join([f'transaction-type/@code="{transaction_type}"'
                            for transaction_type in transaction_types])
    
    path = f'transaction[{type_str}]' + \
           f'[number(translate(transaction-date/@iso-date, "-", "")) >= {year}0101 ' + \
           f'and number(translate(transaction-date/@iso-date, "-", "")) < {year+1}0101]' + \
           f'/value'
    for activity in activities:
        values = activity.etree.xpath(path)
        default_currency = activity.etree.get('default-currency')
        for value in values:
            currency = value.get('currency') or default_currency
            total[currency] += float(value.text)

    print(f'Sum of {transaction_name} for {org_name} in {year}:')
    if total == {}:
        print('  No transactions of that type were found')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': None,
            'value': None,
        }]
    else:
        for currency, value in total.items():
            print(f'  {currency} {value:,.0f}')
        out = [{
            'org_name': org_name,
            'year': year,
            'transaction_type': transaction_name,
            'currency': currency,
            'value': value,
        } for currency, value in total.items()]
    
    return out

# %%
import csv
fieldnames = ['org_name', 'year', 'transaction_type', 'currency', 'value']

org_names = [
    'unocha',
    'ocha_fts'
]
with open('output.csv', 'w') as handler:
    writer = csv.DictWriter(handler, fieldnames=fieldnames)
    writer.writeheader()
    for org_name in org_names:
        for transaction_name in ['commitments', 'spend']:
            for year in [2018, 2017]:
                    output = total_transactions(transaction_name, org_name, year)
                    for o in output:
                        writer.writerow(o)
# Out:
# Sum of commitments for unocha in 2018:
#   No transactions of that type were found
# Sum of commitments for unocha in 2017:
#   No transactions of that type were found
# Sum of spend for unocha in 2018:
#   No transactions of that type were found
# Sum of spend for unocha in 2017:
#   No transactions of that type were found
# Sum of commitments for ocha_fts in 2018:
#   No transactions of that type were found
# Sum of commitments for ocha_fts in 2017:
#   No transactions of that type were found
# Sum of spend for ocha_fts in 2018:
#   No transactions of that type were found
# Sum of spend for ocha_fts in 2017:
#   No transactions of that type were found

# %%
import iatikit

registry = iatikit.data()

beis = registry.publishers.find(name='beis')
print('BEIS has {:,} datasets.'.format(len(beis.datasets)))
# Out:
# BEIS has 28 datasets.

# %%
import iatikit

registry = iatikit.data()

beis = registry.publishers.find(name='beis')
print('BEIS has {:,} activities.'.format(len(beis.activities)))
# Out:
# BEIS has 2,348 activities.

# %%
import iatikit

registry = iatikit.data()

beis = registry.publishers.find(name='beis')
fco = registry.publishers.find(name='fco')
defra = registry.publishers.find(name='defra_transparency')
dwp = registry.publishers.find(name='dwp')
dhsc = registry.publishers.find(name='dhsc')
homeoffice = registry.publishers.find(name='homeoffice')
mod = registry.publishers.find(name='ukmod')
dcms = registry.publishers.find(name='dcms')
dfid = registry.publishers.find(name='dfid')
dfe = registry.publishers.find(name='dfe')

print('beis has {:,} activities.'.format(len(beis.activities)))
print('fco has {:,} activities.'.format(len(fco.activities)))
print('defra has {:,} activities.'.format(len(defra.activities)))
print('dwp has {:,} activities.'.format(len(dwp.activities)))
print('dhsc has {:,} activities.'.format(len(dhsc.activities)))
print('homeoffice has {:,} activities.'.format(len(homeoffice.activities)))
print('mod has {:,} activities.'.format(len(mod.activities)))
print('dcms has {:,} activities.'.format(len(dcms.activities)))
print('dfid has {:,} activities.'.format(len(dfid.activities)))
print('dfe has {:,} activities.'.format(len(dfe.activities)))
# Out:
# beis has 2,348 activities.
# fco has 3,166 activities.
# defra has 119 activities.
# dwp has 1 activities.
# dhsc has 116 activities.
# homeoffice has 6 activities.
# mod has 40 activities.
# dcms has 2 activities.
# dfid has 19,133 activities.
# dfe has 2 activities.

# %%
import csv
fieldnames = ['org_name', 'year', 'transaction_type', 'currency', 'value']

org_names = [
    'beis',
    'fco',
    'defra_transparency',
    'dwp',
    'dhsc',
    'homeoffice',
    'ukmod',
    'dcms',
    'dfid',
    'dfe'
]
with open('output.csv', 'w') as handler:
    writer = csv.DictWriter(handler, fieldnames=fieldnames)
    writer.writeheader()
    for org_name in org_names:
        output = activities()
        for o in output:
            writer.writerow(o)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-9382569d7890> in <module>
#      18     writer.writeheader()
#      19     for org_name in org_names:
# ---> 20         output = activities()
#      21         for o in output:
#      22             writer.writerow(o)
#
# TypeError: 'ActivitySet' object is not callable

# %%
import iatikit
from collections import defaultdict

registry = iatikit.data()
activities = org.activities

type_str = ' or '.join([f'activity/@code="{activity}"'
                            for activity in activities])

path = f'activity[{type_str}]' + \
           f'[number(translate(generated-datetime/@iso-date, "-", "")) >= 20190701 ' + \
           f'and number(translate(generated-datetime/@iso-date, "-", "")) < 20190801]' + \

beis = registry.publishers.find(name='beis')
total_july = len(beis.activities)
print('{:,} beis activities published in July 2019'.format(len(beis.activities)))
# Out:
#   File "<ipython-input-31-b7c029d277e3>", line 13
#
#     ^
# SyntaxError: invalid syntax
